# %% [markdown]
# <a href="https://colab.research.google.com/github/brianbaert/MscThesis/blob/main/MscThesis_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Packages

# %%
# !python --version
# Out:
# Python 3.10.14

# %%
#!pip install avalanche_lib[all]
#!pip install gwpy
#!pip install nds2
# !pip show avalanche-lib
# !pip show gwpy
# Out:
# Name: avalanche-lib
# Version: 0.5.0
# Summary: Avalanche: a Comprehensive Framework for Continual Learning Research
# Home-page: https://github.com/ContinualAI/avalanche
# Author: ContinualAI
# Author-email: contact@continualai.org
# License:
# Location: c:\programdata\anaconda3\envs\mscthesis\lib\site-packages
# Requires: dill, gdown, gputil, matplotlib, numpy, packaging, psutil, pytorchcv, qpsolvers, scikit-learn, tensorboard, torch, torchmetrics, torchvision, tqdm, typing-extensions, wandb
# Required-by:
# Name: gwpy
# Version: 3.0.8
# Summary: A python package for gravitational-wave astrophysics
# Home-page:
# Author:
# Author-email: Duncan Macleod <duncan.macleod@ligo.org>
# License: GPL-3.0-or-later
# Location: c:\programdata\anaconda3\envs\mscthesis\lib\site-packages
# Requires: astropy, dateparser, dqsegdb2, gwdatafind, gwosc, h5py, ligo-segments, ligotimegps, matplotlib, numpy, python-dateutil, requests, scipy, tqdm
# Required-by:

# %%
 #%cd /content/drive/MyDrive/MscThesis
# %pwd
# Out:
# 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis'

# %%
import numpy as np
import os
import pandas as pd
import time

from datetime import datetime
from PIL import Image
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.optim import SGD, Adam, AdamW
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import DatasetFolder, ImageFolder
from tqdm import tqdm
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, \
accuracy_score
from avalanche.models import SlimResNet18
from avalanche.training import Naive, LwF, GenerativeReplay, ICaRLLossPlugin, ICaRL, EWC, AR1
from avalanche.logging import InteractiveLogger, TextLogger
from avalanche.training.plugins import EvaluationPlugin, ReplayPlugin, LwFPlugin, EarlyStoppingPlugin
from avalanche.training.supervised import VAETraining
from avalanche.benchmarks import nc_benchmark
from avalanche.benchmarks.utils import AvalancheDataset
from avalanche.benchmarks.scenarios.dataset_scenario import benchmark_from_datasets
from avalanche.benchmarks.scenarios.supervised import class_incremental_benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, \
timing_metrics, cpu_usage_metrics, StreamConfusionMatrix,disk_usage_metrics, gpu_usage_metrics, \
confusion_matrix_metrics
import multiprocessing as mp

import my_utils
import my_architectures
import my_dataloaders
import my_gwpy_and_fractals

IMG_SIZE = (224,224)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
number_of_workers = mp.cpu_count()
number_of_workers = int(number_of_workers)
print(number_of_workers)
# Out:
# 8

# %% [markdown]
# # DL Baseline

# %%
#train_dir = '/content/drive/MyDrive/MscThesis/GravitySpy/train/train'
train_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\train\\train'
#val_dir = '/content/drive/MyDrive/MscThesis/GravitySpy/validation/validation'
val_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\validation\\validation'
#test_dir = '/content/drive/MyDrive/MscThesis/GravitySpy/test/test'
test_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\test\\test'
#metadata_o3b = '/content/drive/MyDrive/MscThesis/data_o3b_high_confidence.csv'
#metadata_o3a = '/content/drive/MyDrive/MscThesis/data_o3a_high_confidence.csv'
#metadata_o1L1 = '/content/drive/MyDrive/MscThesis/GravitySpy/L1_O1.csv'
#metadata_o2L1 = '/content/drive/MyDrive/MscThesis/GravitySpy/L1_O2.csv'

# %%
#meta_train_v1 = pd.read_csv('/content/drive/MyDrive/MscThesis/GravitySpy/trainingset_v1d1_metadata.csv')
meta_train_v1 = pd.read_csv('C:\\Users\\Brian.Baert\\GravitySpy\\trainingset_v1d1_metadata.csv')
print(meta_train_v1[meta_train_v1['sample_type']=='train']['label'].value_counts())
classes = meta_train_v1['label'].unique()
classes
# Out:
# label
# Blip                   1274
# Koi_Fish                498
# Low_Frequency_Burst     437
# Light_Modulation        361
# Extremely_Loud          316
# Low_Frequency_Lines     315
# Power_Line              314
# Scattered_Light         308
# Violin_Mode             284
# Scratchy                237
# 1080Lines               229
# Whistle                 208
# Helix                   195
# Repeating_Blips         185
# No_Glitch               107
# Tomte                    73
# 1400Ripples              59
# None_of_the_Above        57
# Air_Compressor           41
# Chirp                    41
# Wandering_Line           29
# Paired_Doves             19
# Name: count, dtype: int64
# array(['Whistle', '1080Lines', 'Blip', 'Violin_Mode',
#        'Scattered_Light', 'Power_Line', 'Light_Modulation',
#        'Koi_Fish', 'None_of_the_Above', 'Scratchy', 'Tomte',
#        'Chirp', 'Wandering_Line', 'Extremely_Loud',
#        'Repeating_Blips', 'No_Glitch', 'Low_Frequency_Lines',
#        'Paired_Doves', 'Low_Frequency_Burst', 'Helix',
#        'Air_Compressor', '1400Ripples'], dtype=object)

# %%
classes = my_utils.get_classes_from_dir(train_dir)

# %%
class_to_indx = {c: i for i, c in enumerate(classes)}

# %%
transformGray = transforms.Compose([
     transforms.Resize((140,170)),
     transforms.Grayscale(num_output_channels=1),
     transforms.ToTensor(),
     transforms.Normalize((0.5),(0.5))
    ])

transformRGB = transforms.Compose([
     transforms.Resize((140,170)),
     transforms.Grayscale(num_output_channels=3),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5),(0.5, 0.5, 0.5))
    ])

transformAV = transforms.Compose([
     transforms.Resize((32,32)),
     transforms.ToTensor(),
     transforms.Normalize((0.5),(0.5))
    ])

transformAV_AR1 = transforms.Compose([
     transforms.Resize((224,224)),
     transforms.ToTensor(),
     transforms.Normalize((0.5),(0.5))
    ])

# %%
train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=transformGray)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)
val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=transformGray)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True, num_workers=number_of_workers)
test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=transformGray)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

# %%
train_set = my_dataloaders.GravitySpy_0_5_dataset(root=train_dir, cls=classes, transform=transformGray)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)
val_set = my_dataloaders.GravitySpy_0_5_dataset(root=val_dir, cls=classes, transform=transformGray)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True)
test_set = my_dataloaders.GravitySpy_0_5_dataset(root=test_dir, cls=classes, transform=transformGray)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

# %%
print("The training loader contains {} instances, the val loader contains {} instances and the test loader contains {} instances".format(len(train_loader), len(val_loader), len(test_loader)))
# Out:
# The training loader contains 175 instances, the val loader contains 75 instances and the test loader contains 1180 instances

# %%
class_counts = train_set.count_class_instances()
class_weights = []
for class_name, count in class_counts.items():
  print(f"{class_name}: {count} instances")
  class_weights.append(1.0/(count/len(train_set)))

print(class_weights)
# Out:
# 0: 229 instances
# 1: 59 instances
# 2: 41 instances
# 3: 1274 instances
# 4: 41 instances
# 5: 316 instances
# 6: 195 instances
# 7: 498 instances
# 8: 361 instances
# 9: 437 instances
# 10: 315 instances
# 11: 57 instances
# 12: 107 instances
# 13: 19 instances
# 14: 314 instances
# 15: 185 instances
# 16: 308 instances
# 17: 237 instances
# 18: 73 instances
# 19: 284 instances
# 20: 29 instances
# 21: 208 instances
# [24.397379912663755, 94.6949152542373, 136.26829268292684, 4.385400313971743, 136.26829268292684, 17.680379746835442, 28.651282051282053, 11.218875502008032, 15.476454293628809, 12.784897025171624, 17.736507936507937, 98.01754385964912, 52.21495327102804, 294.0526315789474, 17.792993630573246, 30.2, 18.13961038961039, 23.57383966244726, 76.53424657534246, 19.672535211267604, 192.6551724137931, 26.860576923076923]

# %%
# Create Neural Network architecture for finetuning
myNet = my_architectures.BaselineGrayscaleNet_resnet18()
myNet.to(device)
print(myNet)
# Out:
# C:\ProgramData\anaconda3\envs\MscThesis\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\MscThesis\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# BaselineGrayscaleNet_resnet18(
#   (resnet): ResNet(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=22, bias=True)
#   )
# )

# %%
# Pytorch Training loop
epoch_test_loss = 0
epoch_test_acc = 0
epoch_test_correct = 0
epoch_test_total = 0
best_vloss = 1_000_000.
avg_loss = 0
last_loss = 0
timestamp = my_utils.get_timestamp()

# Define the loss function and optimizer
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)
optimizer = Adam(myNet.parameters(), lr=0.001, weight_decay=1e-3) #LR from the study of Tiago Fernandes

# Number of epochs to train for
num_epochs = 10
epoch_number = 0

start = time.time()
for epoch in range(num_epochs):  # loop over the dataset multiple times
  total_correct = 0
  total_samples = 0
  print('EPOCH {}: '.format(epoch_number + 1))
  train_loss = 0.0
  myNet.train(True)

  ## TRAINING ONE EPOCH
  for i, data in enumerate(train_loader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward + backward + optimize
    outputs = myNet(inputs)
    # compute loss and gradient
    loss = criterion(outputs, labels)
    #add part of regularization
    l2_reg = torch.tensor(0.0)
    for param in myNet.parameters():
      if param.requires_grad: #exclude frozen layers
        l2_reg += torch.norm(param, p=2)
    loss += 1e-5 * l2_reg
    #end part of regularization
    loss.backward()
    # adjust learning weights
    optimizer.step()

    # print statistics
    _, predicted = torch.max(outputs, 1)
    train_loss += loss.item()
    total_correct += (predicted == labels).sum().item()
    total_samples += labels.size(0)

    if i % 16 == 15:
      last_loss = train_loss / 16
      print('  batch {} loss: {}, acc: {}'.format(i+1, last_loss, 100*total_correct/total_samples))
      tb_x = epoch * len(train_loader) + i + 1
      train_loss=0.
    avg_loss = last_loss

  ## VALIDATION
  running_vloss = 0.0
  myNet.eval()

  # disable gradient computation for validation
  with torch.no_grad():
    for i, vdata in enumerate(val_loader):
      vinputs, vlabels = vdata
      vinputs, vlabels = vinputs.to(device), vlabels.to(device)
      voutputs = myNet(vinputs)
      vloss = criterion(voutputs, vlabels)
      running_vloss += vloss
  avg_vloss = running_vloss / (i+1)
  print('LOSS train {:.4f} valid {:.4f} after {} seconds'.format(avg_loss, avg_vloss, time.time()-start))

  if avg_vloss < best_vloss:
    best_vloss = avg_vloss
    model_path = 'model_{}_{}'.format(timestamp, epoch_number)
    torch.save(myNet.state_dict(), model_path)

  #my_utils.checkpoint(myNet, f"epoch-{epoch}.pth")
  epoch_number += 1

end = time.time()
print('Training finished after ', end-start, ' seconds')
# Out:
# EPOCH 1:
#   batch 16 loss: 3.8687445670366287, acc: 31.640625
#   batch 32 loss: 3.0974351167678833, acc: 45.01953125
#   batch 48 loss: 2.8755159080028534, acc: 52.5390625
#   batch 64 loss: 2.9014636427164078, acc: 56.15234375
#   batch 80 loss: 3.0529196858406067, acc: 58.1640625
#   batch 96 loss: 2.8696737587451935, acc: 59.016927083333336
#   batch 112 loss: 2.994697779417038, acc: 60.072544642857146
#   batch 128 loss: 2.7760147750377655, acc: 61.4990234375
#   batch 144 loss: 2.6057771518826485, acc: 62.282986111111114
#   batch 160 loss: 2.705772504210472, acc: 63.30078125
# LOSS train 2.7058 valid 2.8425 after 487.2898406982422 seconds
# EPOCH 2:
#   batch 16 loss: 3.000696137547493, acc: 76.953125
#   batch 32 loss: 2.6400260105729103, acc: 76.46484375
#   batch 48 loss: 2.623463496565819, acc: 77.5390625
#   batch 64 loss: 2.604837477207184, acc: 77.63671875
#   batch 80 loss: 2.427819103002548, acc: 77.6171875
#   batch 96 loss: 2.647399514913559, acc: 76.85546875
#   batch 112 loss: 2.8112524896860123, acc: 75.86495535714286
#   batch 128 loss: 2.807003378868103, acc: 74.951171875
#   batch 144 loss: 2.8706273287534714, acc: 74.71788194444444
#   batch 160 loss: 2.738409161567688, acc: 74.47265625
# LOSS train 2.7384 valid 2.7942 after 928.3058068752289 seconds
# EPOCH 3:
#   batch 16 loss: 2.674668252468109, acc: 77.5390625
#   batch 32 loss: 2.733080580830574, acc: 76.7578125
#   batch 48 loss: 2.760750100016594, acc: 79.03645833333333
#   batch 64 loss: 2.5353563874959946, acc: 78.857421875
#   batch 80 loss: 2.7343104630708694, acc: 78.7890625
#   batch 96 loss: 2.71722025424242, acc: 77.70182291666667
#   batch 112 loss: 2.626043163239956, acc: 78.18080357142857
#   batch 128 loss: 2.566714398562908, acc: 78.7353515625
#   batch 144 loss: 2.566778726875782, acc: 79.01475694444444
#   batch 160 loss: 2.465205192565918, acc: 79.2578125
# LOSS train 2.4652 valid 2.7789 after 1396.778568983078 seconds
# EPOCH 4:
#   batch 96 loss: 2.4213040843605995, acc: 83.56119791666667
#   batch 112 loss: 2.57196693867445, acc: 83.81696428571429
#   batch 128 loss: 2.407929979264736, acc: 84.375
#   batch 144 loss: 2.5005376264452934, acc: 84.89583333333333
#   batch 160 loss: 2.313727617263794, acc: 85.3125
# LOSS train 2.3137 valid 2.6864 after 3946.2070410251617 seconds
# EPOCH 9:
#   batch 16 loss: 2.5644566789269447, acc: 85.7421875
#   batch 32 loss: 2.661117672920227, acc: 86.62109375
#   batch 48 loss: 2.683573417365551, acc: 86.45833333333333
#   batch 64 loss: 2.4660091623663902, acc: 86.328125
#   batch 80 loss: 2.596360854804516, acc: 85.625
#   batch 96 loss: 2.6343355923891068, acc: 85.51432291666667
#   batch 112 loss: 2.559759169816971, acc: 85.07254464285714
#   batch 128 loss: 2.3618426248431206, acc: 85.15625
#   batch 144 loss: 2.469070643186569, acc: 85.32986111111111
#   batch 160 loss: 2.663708448410034, acc: 85.5078125
# LOSS train 2.6637 valid 2.6752 after 4672.318077325821 seconds
# EPOCH 10:
#   batch 16 loss: 2.349911943078041, acc: 87.5
#   batch 32 loss: 2.6904003471136093, acc: 86.81640625
#   batch 48 loss: 2.3779661506414413, acc: 86.39322916666667
#   batch 64 loss: 2.820413887500763, acc: 86.23046875
#   batch 80 loss: 2.668261043727398, acc: 86.7578125
#   batch 96 loss: 2.515599861741066, acc: 87.33723958333333
#   batch 112 loss: 2.534743010997772, acc: 86.94196428571429
#   batch 128 loss: 2.5453865751624107, acc: 86.6943359375
#   batch 144 loss: 2.4355832040309906, acc: 87.00086805555556
#   batch 160 loss: 2.316139057278633, acc: 87.01171875
# LOSS train 2.3161 valid 2.6207 after 5540.504935979843 seconds
# Training finished after  5540.581489562988  seconds

# %%
#save model
#torch.save(myNet.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_baseline_finetune_0_5.pth')
torch.save(myNet.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_baseline_finetune_0_5.pth')
print("Saved Pytorch Model state to thesis_baseline.pth")
# Out:
# Saved Pytorch Model state to thesis_baseline.pth

# %%
#myNet.load_state_dict(torch.load('/content/drive/MyDrive/MscThesis/thesis_baseline_finetune_1_0.pth'))
myNet.load_state_dict(torch.load('C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_baseline_finetune_1_0.pth'))
# Out:
# <All keys matched successfully>

# %%
my_utils.n_test_predictions(myNet, test_loader, classes, 20)
# Out:
# Predicted: "Light_Modulation", Actual: "Light_Modulation"
# Predicted: "Whistle", Actual: "Whistle"
# Predicted: "Power_Line", Actual: "Power_Line"
# Predicted: "1400Ripples", Actual: "1400Ripples"
# Predicted: "Violin_Mode", Actual: "Violin_Mode"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# Predicted: "Whistle", Actual: "Whistle"
# Predicted: "Power_Line", Actual: "Power_Line"
# Predicted: "1080Lines", Actual: "1080Lines"
# Predicted: "Light_Modulation", Actual: "Light_Modulation"
# Predicted: "1080Lines", Actual: "1080Lines"
# Predicted: "Low_Frequency_Lines", Actual: "Low_Frequency_Lines"
# Predicted: "Light_Modulation", Actual: "Light_Modulation"
# Predicted: "Blip", Actual: "Blip"
# Predicted: "None_of_the_Above", Actual: "Low_Frequency_Burst"
# Predicted: "Low_Frequency_Lines", Actual: "Low_Frequency_Lines"
# Predicted: "Repeating_Blips", Actual: "Repeating_Blips"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# Predicted: "Blip", Actual: "Blip"
# Predicted: "1080Lines", Actual: "1080Lines"
# n_test_predictions: 980.4608821868896 ms

# %%
y_pred_list, y_true_list = my_utils.get_predictions(myNet, test_loader)
# Out:
# get_predictions: 52113.90471458435 ms

# %%
# Generate confusion matrix
from sklearn.metrics import f1_score
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,7))

# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)

plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('confusion_matrix_baseline_1_0.png')
plt.close()

# %%
print(f"F1 Score for each class: {f1}")
print(f"The average F1 score is: {f1_score(y_true_list, y_pred_list, average='weighted')}")
# Out:
# F1 Score for each class: [0.96907216 0.85714286 0.88888889 0.97597043 1.
#  0.80373832 1.         0.98076923 0.93959732 0.64661654
#  0.93233083 0.26470588 0.68965517 0.2        0.99270073
#  0.88571429 0.96124031 0.96153846 0.88888889 0.92561983
#  0.44444444 0.95348837]
# The average F1 score is: 0.9109037169739465

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_baseline_1_0.png')
plt.close()

# %% [markdown]
# # CL Base model

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = SlimResNet18(nclasses=22)
model.to(device)
interactive_logger = InteractiveLogger()

# %%
train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=transformAV)
val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=transformAV)
test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=transformAV)

#train_set = my_dataloaders.GravitySpy_0_5_dataset(root=train_dir, cls=classes, transform=transformAV)
#val_set = my_dataloaders.GravitySpy_0_5_dataset(root=val_dir, cls=classes, transform=transformAV)
#test_set = my_dataloaders.GravitySpy_0_5_dataset(root=test_dir, cls=classes, transform=transformAV)

#train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=transformAV_AR1)
#val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=transformAV_AR1)
#test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=transformAV_AR1)

train_set_av = AvalancheDataset(train_set)
train_loader_av = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)

val_set_av = AvalancheDataset(val_set)
val_loader_av = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True, num_workers=number_of_workers)

test_set_av = AvalancheDataset(test_set)
test_loader_av = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)


train_set_av.targets = train_set.labels
test_set_av.targets = test_set.labels
val_set_av.targets = val_set.labels

train_set_av.uniques = list(set(train_set.labels))
test_set_av.uniques = list(set(test_set.labels))
val_set_av.uniques = list(set(val_set.labels))

# %%
bm = nc_benchmark(
    train_dataset=train_set_av,
    test_dataset=val_set_av,
    n_experiences=11,
    shuffle=True,
    seed=123,
    task_labels=False,
)

# %%
# DEFINE THE EVALUATION PLUGIN
# The evaluation plugin manages the metrics computation.
# It takes as argument a list of metrics, collectes their results and returns
# them to the strategy it is attached to.

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True),
    forgetting_metrics(experience=True, stream=True),
    confusion_matrix_metrics(num_classes=bm.n_classes, save_image=True, stream=True),
    loggers=[InteractiveLogger()],
    strict_checks=False,
)

optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-3)
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)

cl_strategy = Naive(
#cl_strategy = LwF(
#cl_strategy = ICaRL(
#cl_strategy= EWC(
#cl_strategy = AR1(
#cl_strategy = VAETraining(
    #model, optimizer, criterion, ewc_lambda=5.5, train_epochs=10, mode='online', decay_factor=0.05, keep_importance_data=True, train_mb_size=32, eval_mb_size=16, device=device
    model, optimizer, criterion, train_mb_size=32, train_epochs=10, eval_mb_size=16, device=device, plugins=[eval_plugin, ReplayPlugin(mem_size=2000), EarlyStoppingPlugin(patience=2, val_stream_name='valid')]
)

# %%
for experience in bm.train_stream:
  print(experience.classes_in_this_experience)
# Out:
# [2, 14]
# [4, 15]
# [0, 3]
# [9, 12]
# [11, 13]
# [17, 21]
# [18, 20]
# [1, 10]
# [16, 6]
# [8, 19]
# [5, 7]

# %%
print('Starting experiment...')
results = []
for experience in bm.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    cl_strategy.train(experience, num_workers=0)
    print('Training completed')
# Out:
# Starting experiment...
# Start of experience:  0
# Current Classes:  [2, 14]
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1109
# 	Loss_MB/train_phase/train_stream/Task000 = 3.3159
# 	Time_Epoch/train_phase/train_stream/Task000 = 13.1170
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8648
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6667
# 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1109
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8648
# 100%|██████████| 12/12 [00:08<00:00,  1.46it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8259
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8326
# 	Time_Epoch/train_phase/train_stream/Task000 = 8.2227
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9831
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:08<00:00,  1.46it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8259
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9831
# 100%|██████████| 12/12 [00:08<00:00,  1.49it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7366
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9875
# 	Time_Epoch/train_phase/train_stream/Task000 = 8.0308
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:08<00:00,  1.50it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7366
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6889
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7736
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.8365
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6889
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7010
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0152
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.8437
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7010
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.54it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6535
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7690
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.8082
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6535
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6612
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7690
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.8591
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6612
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.50it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6541
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0261
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.9678
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.50it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6541
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.56it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7064
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7570
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.7108
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.56it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7064
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.51it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7072
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9833
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.9447
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.51it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7072
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Start of experience:  1
# Current Classes:  [4, 15]
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# 100%|██████████| 8/8 [00:11<00:00,  1.49s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3585
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6712
# 	Time_Epoch/train_phase/train_stream/Task000 = 11.9490
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5768
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.1765
# 100%|██████████| 8/8 [00:11<00:00,  1.49s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3585
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5768
# 100%|██████████| 8/8 [00:09<00:00,  1.18s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5517
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3818
# 	Time_Epoch/train_phase/train_stream/Task000 = 9.4259
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9046
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6471
# 100%|██████████| 8/8 [00:09<00:00,  1.18s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5517
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9046
# 100%|██████████| 8/8 [00:09<00:00,  1.22s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4694
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8190
# 	Time_Epoch/train_phase/train_stream/Task000 = 9.7360
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9813
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9412
# 100%|██████████| 8/8 [00:09<00:00,  1.22s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4694
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9813
# 100%|██████████| 8/8 [00:09<00:00,  1.22s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4012
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1816
# 	Time_Epoch/train_phase/train_stream/Task000 = 9.7736
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9917
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9118
# 100%|██████████| 8/8 [00:09<00:00,  1.22s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4012
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9917
# 100%|██████████| 8/8 [00:10<00:00,  1.28s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4143
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6645
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.2318
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9706
# 100%|██████████| 8/8 [00:10<00:00,  1.28s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4143
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:11<00:00,  1.40s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3176
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6029
# 	Time_Epoch/train_phase/train_stream/Task000 = 11.1607
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:11<00:00,  1.40s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3176
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:10<00:00,  1.27s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3755
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4843
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.1216
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.27s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3755
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:10<00:00,  1.32s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3549
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7755
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.5584
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.32s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3549
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:10<00:00,  1.34s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3311
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4600
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.6975
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.34s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3311
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:09<00:00,  1.13s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3665
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3468
# 	Time_Epoch/train_phase/train_stream/Task000 = 9.0623
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:09<00:00,  1.13s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3665
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Start of experience:  2
# Current Classes:  [0, 3]
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# 100%|██████████| 47/47 [01:03<00:00,  1.35s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3277
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2706
# 	Time_Epoch/train_phase/train_stream/Task000 = 63.4097
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7714
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9048
# 100%|██████████| 47/47 [01:03<00:00,  1.35s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3277
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7714
# 100%|██████████| 47/47 [00:49<00:00,  1.06s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1678
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1294
# 	Time_Epoch/train_phase/train_stream/Task000 = 49.8586
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9387
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 47/47 [00:49<00:00,  1.06s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1678
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9387
# 100%|██████████| 47/47 [00:50<00:00,  1.07s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1501
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2757
# 	Time_Epoch/train_phase/train_stream/Task000 = 50.1756
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9705
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9841
# 100%|██████████| 47/47 [00:50<00:00,  1.07s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1501
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9705
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1857
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3534
# 	Time_Epoch/train_phase/train_stream/Task000 = 51.1021
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9651
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9683
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1857
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9651
# 100%|██████████| 47/47 [00:52<00:00,  1.12s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1950
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1258
# 	Time_Epoch/train_phase/train_stream/Task000 = 52.5505
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9763
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 47/47 [00:52<00:00,  1.12s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1950
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9763
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1540
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7874
# 	Time_Epoch/train_phase/train_stream/Task000 = 51.2477
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9881
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1540
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9881
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1635
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6269
# 	Time_Epoch/train_phase/train_stream/Task000 = 51.0970
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9888
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9683
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1635
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9888
# 100%|██████████| 47/47 [00:50<00:00,  1.08s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1150
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1621
# 	Time_Epoch/train_phase/train_stream/Task000 = 50.7592
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9888
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 47/47 [00:50<00:00,  1.08s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1150
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9888
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1707
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2852
# 	Time_Epoch/train_phase/train_stream/Task000 = 51.1166
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9865
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 47/47 [00:51<00:00,  1.09s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1707
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9865
# 100%|██████████| 47/47 [00:50<00:00,  1.08s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1410
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9897
# 	Time_Epoch/train_phase/train_stream/Task000 = 50.5356
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9895
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 47/47 [00:50<00:00,  1.08s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.
/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0929
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9648
# 100%|██████████| 26/26 [00:28<00:00,  1.10s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1717
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7444
# 	Time_Epoch/train_phase/train_stream/Task000 = 28.6372
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9423
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9130
# 100%|██████████| 26/26 [00:28<00:00,  1.10s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1717
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9423
# 100%|██████████| 26/26 [00:28<00:00,  1.08s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0706
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4708
# 	Time_Epoch/train_phase/train_stream/Task000 = 28.1597
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9405
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9783
# 100%|██████████| 26/26 [00:28<00:00,  1.08s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0706
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9405
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed

# %%
#save model
torch.save(model.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_Naive_CL_1_0.pth')
#torch.save(model.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_generative_CL_1_0.pth')
print("Saved Pytorch Model state to thesis_EWC_CL_1_0.pth")
# Out:
# Saved Pytorch Model state to thesis_EWC_CL_1_0.pth

# %%
model = SlimResNet18(nclasses=22)
model.load_state_dict(torch.load('C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_Naive_CL_1_0.pth'))
#model.load_state_dict(torch.load('/content/drive/MyDrive/MscThesis/thesis_generative_CL_1_0.pth'))
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(20, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(20, 40, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(40, 80, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(40, 80, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(80, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(80, 160, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=160, out_features=22, bias=True)
# )

# %%
my_utils.n_test_predictions(model, test_loader_av, classes, 20)
# Out:
# Predicted: "Blip", Actual: "Blip"
# Predicted: "Low_Frequency_Lines", Actual: "Low_Frequency_Lines"
# Predicted: "Light_Modulation", Actual: "Light_Modulation"
# Predicted: "1400Ripples", Actual: "1400Ripples"
# Predicted: "Low_Frequency_Burst", Actual: "Low_Frequency_Burst"
# Predicted: "Light_Modulation", Actual: "Light_Modulation"
# Predicted: "Paired_Doves", Actual: "Blip"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# Predicted: "Low_Frequency_Burst", Actual: "Low_Frequency_Burst"
# Predicted: "Repeating_Blips", Actual: "Repeating_Blips"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# Predicted: "Low_Frequency_Lines", Actual: "Low_Frequency_Lines"
# Predicted: "Koi_Fish", Actual: "Blip"
# Predicted: "Light_Modulation", Actual: "Light_Modulation"
# Predicted: "Paired_Doves", Actual: "Helix"
# Predicted: "Blip", Actual: "Blip"
# Predicted: "Power_Line", Actual: "Power_Line"
# Predicted: "Extremely_Loud", Actual: "Light_Modulation"
# Predicted: "No_Glitch", Actual: "No_Glitch"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# n_test_predictions: 680.8726787567139 ms

# %%
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# get_predictions: 30234.273195266724 ms

# %%
# Generate confusion matrix
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
plt.figure(figsize=(10,7))

# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)

plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_Naive_1_0.png')
plt.close()

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_Naive_1_0.png')
plt.close()

# %%
cl_strategy = LwF(
    model, optimizer, criterion, alpha=0.5, temperature=2.0,train_mb_size=32, train_epochs=10, eval_mb_size=16, device=device, plugins=[eval_plugin, ReplayPlugin(mem_size=2000), EarlyStoppingPlugin(patience=2, val_stream_name='valid')]
)

# %%
print('Starting experiment with LwF...')
results = []
for experience in bm.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    cl_strategy.train(experience, num_workers=0)
    print('Training completed')
# Out:
# Starting experiment with LwF...
# Start of experience:  0
# Current Classes:  [2, 14]
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# 100%|██████████| 12/12 [00:09<00:00,  1.29it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0950
# 	Loss_MB/train_phase/train_stream/Task000 = 3.3004
# 	Time_Epoch/train_phase/train_stream/Task000 = 9.3018
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7070
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.6667
# 100%|██████████| 12/12 [00:09<00:00,  1.29it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0950
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7070
# 100%|██████████| 12/12 [00:06<00:00,  1.83it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7021
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9734
# 	Time_Epoch/train_phase/train_stream/Task000 = 6.5464
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.83it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7021
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 100%|██████████| 12/12 [00:07<00:00,  1.70it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7689
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7895
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.0498
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.70it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7689
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9944
# 100%|██████████| 12/12 [00:07<00:00,  1.69it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7150
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0137
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.1115
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.69it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7150
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.78it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6770
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7751
# 	Time_Epoch/train_phase/train_stream/Task000 = 6.7593
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.78it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6770
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.67it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6588
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9849
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.1697
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.67it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6588
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.77it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7515
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7594
# 	Time_Epoch/train_phase/train_stream/Task000 = 6.7903
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.77it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7515
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.66it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7078
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9751
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.2381
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.66it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7078
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.72it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6493
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7591
# 	Time_Epoch/train_phase/train_stream/Task000 = 6.9633
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:06<00:00,  1.73it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6493
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.64it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6653
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7547
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.2989
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 12/12 [00:07<00:00,  1.64it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6653
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Start of experience:  1
# Current Classes:  [4, 15]
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# 100%|██████████| 8/8 [00:11<00:00,  1.45s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8183
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3988
# 	Time_Epoch/train_phase/train_stream/Task000 = 11.5946
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8195
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:11<00:00,  1.45s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8183
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8195
# 100%|██████████| 8/8 [00:10<00:00,  1.37s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4328
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3743
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.9785
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9793
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.7647
# 100%|██████████| 8/8 [00:10<00:00,  1.37s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4328
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9793
# 100%|██████████| 8/8 [00:10<00:00,  1.33s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3845
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7203
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.6117
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9917
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9412
# 100%|██████████| 8/8 [00:10<00:00,  1.33s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3845
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9917
# 100%|██████████| 8/8 [00:10<00:00,  1.26s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4063
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8156
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.0502
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.26s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4063
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:10<00:00,  1.33s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3885
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0901
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.6723
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.33s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3885
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:10<00:00,  1.32s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3565
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4764
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.5558
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.32s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3565
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.26s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3905
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2156
# 	Time_Epoch/train_phase/train_stream/Task000 = 10.0859
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:10<00:00,  1.26s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3905
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 100%|██████████| 8/8 [00:12<00:00,  1.54s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3741
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4946
# 	Time_Epoch/train_phase/train_stream/Task000 = 12.3355
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9917
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:12<00:00,  1.54s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3741
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9917
# 100%|██████████| 8/8 [00:12<00:00,  1.54s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3956
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3604
# 	Time_Epoch/train_phase/train_stream/Task000 = 12.2929
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9959
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 8/8 [00:12<00:00,  1.54s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3956
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9959
# 100%|██████████| 8/8 [00:09<00:00,  1.18s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3816
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0494
# 	Time_Epoch/train_phase/train_stream/Task000 = 9.4525
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9706
# 100%|██████████| 8/8 [00:09<00:00,  1.18s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3816
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9979
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Start of experience:  2
# Current Classes:  [0, 3]
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# 100%|██████████| 47/47 [01:19<00:00,  1.69s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3655
# 	Loss_MB/train_phase/train_stream/Task000 = 2.
/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1375
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0883
# 	Time_Epoch/train_phase/train_stream/Task000 = 40.5052
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9131
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9130
# 100%|██████████| 26/26 [00:40<00:00,  1.56s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1375
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9131
# 100%|██████████| 26/26 [00:36<00:00,  1.40s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2458
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5048
# 	Time_Epoch/train_phase/train_stream/Task000 = 36.5184
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9380
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9565
# 100%|██████████| 26/26 [00:36<00:00,  1.40s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2458
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9380
# 100%|██████████| 26/26 [00:49<00:00,  1.92s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3118
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1662
# 	Time_Epoch/train_phase/train_stream/Task000 = 49.9070
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9502
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.8478
# 100%|██████████| 26/26 [00:49<00:00,  1.92s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3118
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9502
# 100%|██████████| 26/26 [00:49<00:00,  1.91s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2557
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5901
# 	Time_Epoch/train_phase/train_stream/Task000 = 49.5440
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9392
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9783
# 100%|██████████| 26/26 [00:49<00:00,  1.91s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2557
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9392
# 100%|██████████| 26/26 [00:41<00:00,  1.59s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2216
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9098
# 	Time_Epoch/train_phase/train_stream/Task000 = 41.4263
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9228
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9565
# 100%|██████████| 26/26 [00:41<00:00,  1.59s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2216
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9228
# 100%|██████████| 26/26 [00:38<00:00,  1.47s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1639
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8060
# 	Time_Epoch/train_phase/train_stream/Task000 = 38.1032
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9386
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9348
# 100%|██████████| 26/26 [00:38<00:00,  1.47s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1639
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9386
# 100%|██████████| 26/26 [00:38<00:00,  1.50s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1809
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7298
# 	Time_Epoch/train_phase/train_stream/Task000 = 38.9343
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9399
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9783
# 100%|██████████| 26/26 [00:38<00:00,  1.50s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1809
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9399
# 100%|██████████| 26/26 [00:36<00:00,  1.42s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2974
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3973
# 	Time_Epoch/train_phase/train_stream/Task000 = 36.8211
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9575
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.8478
# 100%|██████████| 26/26 [00:36<00:00,  1.42s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2974
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9575
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed

# %%
#save model
torch.save(model.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_LwF_CL_1_0.pth')
#torch.save(model.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_generative_CL_1_0.pth')
print("Saved Pytorch Model state to thesis_LwF_CL_1_0.pth")

#calculate predictions
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# Saved Pytorch Model state to thesis_LwF_CL_1_0.pth
# get_predictions: 34550.06742477417 ms

# %%
# Generate confusion matrix
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
plt.figure(figsize=(10,7))
# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_LwF_1_0.png')
plt.close()

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_LwF_1_0.png')
plt.close()
