# %% [markdown]
# <a href="https://colab.research.google.com/github/brianbaert/MscThesis/blob/main/MscThesis_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Packages

# %%
# !python --version
#!pip install avalanche_lib[all]
#!pip install gwpy
#!pip install nds2
#!pip show avalanche-lib
#!pip show gwpy
# Out:
# Python 3.10.14

# %%
#%cd /content/drive/MyDrive/MscThesis
# %pwd
# Out:
# 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis'

# %%
import numpy as np
import os
import pandas as pd
import time

from datetime import datetime
from PIL import Image
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.optim as optim
import torchvision
import torchvision.models
import torchvision.transforms as transforms
from torch.optim import SGD, Adam, AdamW
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import DatasetFolder, ImageFolder
from tqdm import tqdm
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, \
accuracy_score
from avalanche.models import SlimResNet18, MTSlimResNet18, SimpleCNN
from avalanche.models import as_multitask, IncrementalClassifier
from avalanche.models.utils import avalanche_model_adaptation
from avalanche.training import Naive, LwF, GenerativeReplay, ICaRLLossPlugin, ICaRL, EWC, AR1, LFL, AGEM
from avalanche.logging import InteractiveLogger, TextLogger
from avalanche.training.plugins import EvaluationPlugin, ReplayPlugin, LwFPlugin, EarlyStoppingPlugin, AGEMPlugin
from avalanche.training.plugins.lr_scheduling import LRSchedulerPlugin
from avalanche.benchmarks import nc_benchmark
from avalanche.benchmarks.utils import AvalancheDataset
from avalanche.benchmarks.scenarios.dataset_scenario import benchmark_from_datasets
from avalanche.benchmarks.scenarios.supervised import class_incremental_benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, \
timing_metrics, cpu_usage_metrics, StreamConfusionMatrix,disk_usage_metrics, gpu_usage_metrics, \
confusion_matrix_metrics
import multiprocessing as mp

import my_utils
import my_architectures
import my_dataloaders
import my_gwpy_and_fractals
import my_transformations

IMG_SIZE = (224,224)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# calculating the amount of workers usable
number_of_workers = mp.cpu_count()
number_of_workers = int(number_of_workers/2)
print(number_of_workers)
# Out:
# 4

# %%
# Setting the correct directories
train_dir2 = 'C:\\Users\\Brian.Baert\\TrainingSet'
train_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\train\\train'
val_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\validation\\validation'
test_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\test\\test'

# Read in class labels
class_file = open("classes.txt", "r")
classes = class_file.read()
classes = classes.split(", ")

# Read in inverse weights used to cope with the imbalanced dataset
class_weights_file = open("class_weights.txt", "r")
temp = class_weights_file.read()
temp_split = temp.split(", ")
class_weights =  [float(weight) for weight in temp_split]

# %%
meta_train_v1 = pd.read_csv('C:\\Users\\Brian.Baert\\GravitySpy\\trainingset_v1d1_metadata.csv')
print(meta_train_v1[meta_train_v1['sample_type']=='train']['label'].value_counts())
classes = meta_train_v1['label'].unique()

# %% [markdown]
# # DL Baseline

# %%
train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=my_transformations.transformGray)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)
val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=my_transformations.transformGray)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True, num_workers=number_of_workers)
test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=my_transformations.transformGray)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

# %%
train_set = my_dataloaders.GravitySpy_0_5_dataset(root=train_dir, cls=classes, transform=my_transformations.transformGray)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)
val_set = my_dataloaders.GravitySpy_0_5_dataset(root=val_dir, cls=classes, transform=my_transformations.transformGray)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True)
test_set = my_dataloaders.GravitySpy_0_5_dataset(root=test_dir, cls=classes, transform=my_transformations.transformGray)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

# %%
print("The training loader contains {} instances, the val loader contains {} instances and the test loader contains {} instances".format(len(train_loader), len(val_loader), len(test_loader)))

# %%
class_counts = train_set.count_class_instances()
class_weights = []
for class_name, count in class_counts.items():
  print(f"{class_name}: {count} instances")
  class_weights.append(1.0/(count/len(train_set)))

class_weights

with open("class_weights.txt", "w") as output:
    output.write(str(class_weights))

# %%
# Create Neural Network architecture for finetuning
myNet = my_architectures.BaselineGrayscaleNet_resnet18()
myNet.to(device)
print(myNet)

# %%
# Pytorch Training loop
epoch_test_loss = 0
epoch_test_acc = 0
epoch_test_correct = 0
epoch_test_total = 0
best_vloss = 1_000_000.
avg_loss = 0
last_loss = 0
timestamp = my_utils.get_timestamp()

# Define the loss function and optimizer
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)
optimizer = Adam(myNet.parameters(), lr=0.001, weight_decay=1e-3) #LR from the study of Tiago Fernandes

# Number of epochs to train for
num_epochs = 10
epoch_number = 0

start = time.time()
for epoch in range(num_epochs):  # loop over the dataset multiple times
  total_correct = 0
  total_samples = 0
  print('EPOCH {}: '.format(epoch_number + 1))
  train_loss = 0.0
  myNet.train(True)

  ## TRAINING ONE EPOCH
  for i, data in enumerate(train_loader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward + backward + optimize
    outputs = myNet(inputs)
    # compute loss and gradient
    loss = criterion(outputs, labels)
    #add part of regularization
    l2_reg = torch.tensor(0.0)
    for param in myNet.parameters():
      if param.requires_grad: #exclude frozen layers
        l2_reg += torch.norm(param, p=2)
    loss += 1e-5 * l2_reg
    #end part of regularization
    loss.backward()
    # adjust learning weights
    optimizer.step()

    # print statistics
    _, predicted = torch.max(outputs, 1)
    train_loss += loss.item()
    total_correct += (predicted == labels).sum().item()
    total_samples += labels.size(0)

    if i % 16 == 15:
      last_loss = train_loss / 16
      print('  batch {} loss: {}, acc: {}'.format(i+1, last_loss, 100*total_correct/total_samples))
      tb_x = epoch * len(train_loader) + i + 1
      train_loss=0.
    avg_loss = last_loss

  ## VALIDATION
  running_vloss = 0.0
  myNet.eval()

  # disable gradient computation for validation
  with torch.no_grad():
    for i, vdata in enumerate(val_loader):
      vinputs, vlabels = vdata
      vinputs, vlabels = vinputs.to(device), vlabels.to(device)
      voutputs = myNet(vinputs)
      vloss = criterion(voutputs, vlabels)
      running_vloss += vloss
  avg_vloss = running_vloss / (i+1)
  print('LOSS train {:.4f} valid {:.4f} after {} seconds'.format(avg_loss, avg_vloss, time.time()-start))

  if avg_vloss < best_vloss:
    best_vloss = avg_vloss
    model_path = 'model_{}_{}'.format(timestamp, epoch_number)
    torch.save(myNet.state_dict(), model_path)

  #my_utils.checkpoint(myNet, f"epoch-{epoch}.pth")
  epoch_number += 1

end = time.time()
print('Training finished after ', end-start, ' seconds')

# %%
#save model
#torch.save(myNet.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_baseline_finetune_0_5.pth')
torch.save(myNet.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_baseline_finetune_0_5.pth')
print("Saved Pytorch Model state to thesis_baseline.pth")

# %%
#myNet.load_state_dict(torch.load('/content/drive/MyDrive/MscThesis/thesis_baseline_finetune_1_0.pth'))
myNet.load_state_dict(torch.load('C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_baseline_finetune_1_0.pth'))

# %%
my_utils.n_test_predictions(myNet, test_loader, classes, 20)

# %%
y_pred_list, y_true_list = my_utils.get_predictions(myNet, test_loader)

# %%
# Generate confusion matrix
from sklearn.metrics import f1_score
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,7))

# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)

plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('confusion_matrix_baseline_1_0.png')
plt.close()

# %%
print(f"F1 Score for each class: {f1}")
print(f"The average F1 score is: {f1_score(y_true_list, y_pred_list, average='weighted')}")

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_baseline_1_0.png')
plt.close()

# %% [markdown]
# # CL Experiments

# %% [markdown]
# ## Model, dataloader, benchmark and eval plugin

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = my_architectures.BaselineColorNet_resnet18()
model.to(device)

classes = my_utils.get_classes_from_dir(train_dir2)
class_to_indx = my_utils.classes_to_indices(classes)

# %%
train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir2, cls=classes, transform=my_transformations.transformAV_224_Crop)
val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=my_transformations.transformAV_224)
test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=my_transformations.transformAV_224)

train_set_av = AvalancheDataset(train_set)
train_loader_av = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)

val_set_av = AvalancheDataset(val_set)
val_loader_av = torch.utils.data.DataLoader(val_set, batch_size=32, shuffle=True, num_workers=number_of_workers)

test_set_av = AvalancheDataset(test_set)
test_loader_av = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

train_set_av.targets = train_set.labels
test_set_av.targets = test_set.labels
val_set_av.targets = val_set.labels

train_set_av.uniques = list(set(train_set.labels))
test_set_av.uniques = list(set(test_set.labels))
val_set_av.uniques = list(set(val_set.labels))

# %%
# DEFINE THE BENCHMARK
# CL custom benchmark, here we opt for the generator New Classes (NC)
# Given a sequence of train and test datasets this creates the continual stream as a series of experiences.
bm = nc_benchmark(
    train_dataset=train_set_av,
    test_dataset=val_set_av,
    n_experiences=11,
    shuffle=True,
    seed=1234,
    task_labels=False,
    class_ids_from_zero_in_each_exp=False,
)

# %%
# DEFINE THE EVALUATION PLUGIN
# The evaluation plugin manages the metrics computation. It takes as argument a list of metrics, collectes their results and returns
# them to the strategy it is attached to.

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(experience=True),
    forgetting_metrics(experience=True, stream=True),
    loggers=[InteractiveLogger()],
    strict_checks=False,
)

# %%
#model.to(device)
#interactive_logger = InteractiveLogger()

# %%
my_utils.plot_first_image(train_loader_av)

# %%
my_utils.plot_first_image(val_loader_av)

# %%
my_utils.plot_first_image(test_loader_av)

# %% [markdown]
# ## Naive strategy with cross entropy loss and adam

# %%
# OPTIMIZER and CRITERION
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)

# %%
# NAIVE STRATEG
cl_strategy = Naive(
    model=model, optimizer=optimizer, criterion=criterion, train_mb_size=32, train_epochs=20, 
    eval_mb_size=16, device=device, evaluator=eval_plugin, 
    plugins=[ReplayPlugin(mem_size=2*len(train_set)), EarlyStoppingPlugin(patience=2, val_stream_name='valid')]
)

# %%
# TRAINING
results=[]
results = my_utils.cl_simple_train_loop(bm, cl_strategy, model, optimizer, number_of_workers)
# Out:
# Starting experiment with strategy: <avalanche.training.supervised.strategy_wrappers.Naive object at 0x0000029FA17A3B50>
# Start of experience:  0
# Current Classes:  [19, 5]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 4/4 [00:14<00:00,  3.67s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.2374
# 	Loss_MB/train_phase/train_stream/Task000 = 3.8083
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4300
# 100%|██████████| 4/4 [00:14<00:00,  3.58s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.5067
# 	Loss_MB/train_phase/train_stream/Task000 = 3.3116
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9500
# 100%|██████████| 4/4 [00:15<00:00,  3.86s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1909
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9564
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9800
# 100%|██████████| 4/4 [00:15<00:00,  3.83s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1963
# 	Loss_MB/train_phase/train_stream/Task000 = 3.4030
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9600
# 100%|██████████| 4/4 [00:14<00:00,  3.62s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9997
# 	Loss_MB/train_phase/train_stream/Task000 = 4.5848
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9600
# 100%|██████████| 4/4 [00:14<00:00,  3.57s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9556
# 	Loss_MB/train_phase/train_stream/Task000 = 3.0260
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9400
# 100%|██████████| 4/4 [00:12<00:00,  3.16s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8396
# 	Loss_MB/train_phase/train_stream/Task000 = 3.2348
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9800
# 100%|██████████| 4/4 [00:12<00:00,  3.11s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8062
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1259
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9500
# 100%|██████████| 4/4 [00:11<00:00,  2.98s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8140
# 	Loss_MB/train_phase/train_stream/Task000 = 3.2842
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9700
# 100%|██████████| 4/4 [00:12<00:00,  3.08s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7680
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7647
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 4/4 [00:12<00:00,  3.11s/it]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7919
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7406
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9800
# 100%|██████████| 4/4 [00:12<00:00,  3.18s/it]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7758
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7619
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9800
# 100%|██████████| 4/4 [00:12<00:00,  3.15s/it]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7686
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7786
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 4/4 [00:11<00:00,  2.94s/it]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7695
# 	Loss_MB/train_phase/train_stream/Task000 = 3.2555
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9900
# 100%|██████████| 4/4 [00:12<00:00,  3.08s/it]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9222
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9257
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8900
# 100%|██████████| 4/4 [00:12<00:00,  3.16s/it]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7783
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7141
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9800
# 100%|██████████| 4/4 [00:12<00:00,  3.21s/it]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7511
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8188
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9900
# 100%|██████████|
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp010 = 0.9800
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 1.2455
# 	StreamForgetting/eval_phase/train_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.9800

# %%
# SAVE MODEL
my_utils.checkpoint(model, 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_Naive_CL_1_0.pth')
# Out:
# Saved Pytorch model state to  C:\Users\Brian.Baert\Documents\GitHub\MscThesis\Models\thesis_Naive_CL_1_0.pth

# %%
# SOME TEST PREDICTIONS
my_utils.n_test_predictions(model, test_loader_av, classes, 20)
# Out:
# Predicted: "Scattered_Light", Actual: "Scattered_Light"
# Predicted: "Whistle", Actual: "Blip"
# Predicted: "No_Glitch", Actual: "Blip"
# Predicted: "Repeating_Blips", Actual: "Blip"
# Predicted: "Repeating_Blips", Actual: "Blip"
# Predicted: "1400Ripples", Actual: "Whistle"
# Predicted: "Whistle", Actual: "Light_Modulation"
# Predicted: "Extremely_Loud", Actual: "Light_Modulation"
# Predicted: "Helix", Actual: "Light_Modulation"
# Predicted: "Repeating_Blips", Actual: "Repeating_Blips"
# Predicted: "No_Glitch", Actual: "Power_Line"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# Predicted: "1400Ripples", Actual: "Violin_Mode"
# Predicted: "No_Glitch", Actual: "Scattered_Light"
# Predicted: "Extremely_Loud", Actual: "Extremely_Loud"
# Predicted: "Koi_Fish", Actual: "Koi_Fish"
# Predicted: "No_Glitch", Actual: "Low_Frequency_Burst"
# Predicted: "Air_Compressor", Actual: "Low_Frequency_Burst"
# Predicted: "Repeating_Blips", Actual: "Blip"
# Predicted: "No_Glitch", Actual: "Blip"
# n_test_predictions: 1555.8066368103027 ms

# %%
# CALCULATE ALL PREDICTIONS
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# get_predictions: 80898.3199596405 ms

# %%
# GENERATE CONFUSION MATRIX AND F1
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
# PLOT CM
my_utils.plot_confusion_matrix(cm, classes, 'cm_Naive_1_0.png')

# %%
# PLOT F1
my_utils.plot_f1_scores(f1, classes, 'f1_scores_Naive_1_0.png')

# %% [markdown]
# ## LwF strategy with cross entropy loss and adam optimizer
# The experiments are done on a neural network starting with 2 output nodes and gradually adapting with each experience to 22, but also on a neural network with 22 output nodes and running over the experiences.

# %%
# SETTING UP DEVICE AND INSTANCE OF MODEL CLASS
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = my_architectures.BaselineColorNet_resnet18()
model.to(device)

# %%
# OPTIMIZER and LOSS CRITERION
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)

# %%
# STRATEGY 
# ALPHA AND TEMPERATURE are taken from the paper by Oren & Wolf - "In defense of the Learning Without Forgetting for Task Incremental Learning"
cl_strategy = LwF(
    model=model, optimizer=optimizer, criterion=criterion, alpha=0.25, temperature=2.0, 
    train_mb_size=64, train_epochs=20, eval_mb_size=32, device=device, evaluator=eval_plugin, 
    plugins=[ReplayPlugin(mem_size=2*len(train_set))] #Early stopping is not used here because LwF does not inherently support Early Stopping
)

# %%
# TRAINING
results=[]
results = my_utils.cl_simple_train_loop(bm, cl_strategy, model, optimizer, number_of_workers)
# Out:
# Starting experiment with strategy: <avalanche.training.supervised.strategy_wrappers.LwF object at 0x0000029FA5A7ED40>
# Start of experience:  0
# Current Classes:  [19, 5]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 2/2 [00
/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3028
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3043
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5439
# 100%|██████████| 2/2 [00:49<00:00, 24.59s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1229
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1773
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5746
# 100%|██████████| 2/2 [00:47<00:00, 23.52s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1197
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2126
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5658
# 100%|██████████| 2/2 [00:35<00:00, 17.81s/it]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1064
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1370
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6535
# 100%|██████████| 2/2 [00:36<00:00, 18.03s/it]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0532
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0306
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7325
# 100%|██████████| 2/2 [00:36<00:00, 18.18s/it]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0155
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0152
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6930
# 100%|██████████| 2/2 [00:35<00:00, 17.69s/it]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9952
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9335
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7719
# 100%|██████████| 2/2 [00:34<00:00, 17.39s/it]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0275
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0589
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8070
# 100%|██████████| 2/2 [00:35<00:00, 17.99s/it]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0883
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1297
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7632
# 100%|██████████| 2/2 [00:35<00:00, 17.59s/it]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0676
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0304
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7895
# 100%|██████████| 2/2 [00:35<00:00, 17.91s/it]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9735
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0167
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8246
# 100%|██████████| 2/2 [00:34<00:00, 17.41s/it]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9842
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9985
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8158
# 100%|██████████| 2/2 [00:34<00:00, 17.45s/it]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0315
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0504
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8202
# -- >> End of training phase << --
# Training completed
# -- >> Start of eval phase << --
# -- Starting eval on experience 10 (Task 0) from train stream --
# 100%|██████████| 4/4 [00:05<00:00,  1.44s/it]
# > Eval on experience 10 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp010 = 1.2318
# 	Time_Exp/eval_phase/train_stream/Task000/Exp010 = 5.7690
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp010 = 0.9200
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 1.2318
# 	StreamForgetting/eval_phase/train_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.9200

# %%
# SAVE MODEL
my_utils.checkpoint(model, 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_LwF_CL_1_0.pth')
# Out:
# Saved Pytorch model state to  C:\Users\Brian.Baert\Documents\GitHub\MscThesis\Models\thesis_LwF_CL_1_0.pth

# %%
# CALCULATE ALL PREDICTIONS
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# get_predictions: 80857.90276527405 ms

# %%
# GENERATE CONFUSION MATRIX AND F1
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
# PLOT CM
my_utils.plot_confusion_matrix(cm, classes, 'cm_LwF_1_0.png')

# %%
# PLOT F1
my_utils.plot_f1_scores(f1, classes, 'f1_scores_LwF_1_0.png')

# %% [markdown]
# According to Oren & Wolf ("In defense of the learning without forgetting for task incremental learning"), LwF mostly benefits from a Wide-ResNet netwrok rather than from deeper networks.

# %% [markdown]
# ## AGEM strategy with cross entropy loss and adam

# %%
model = my_architectures.BaselineColorNet_resnet18()
model.to(device)

# %%
# OPTIMIZER AND LOSS CRITERION
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)

# %%
# STRATEGY
cl_strategy = AGEM(
    model=model, optimizer=optimizer, criterion=criterion, patterns_per_exp=11,
    train_mb_size=64, train_epochs=20, eval_mb_size=32, device=device, evaluator=eval_plugin,
    plugins=[ReplayPlugin(mem_size=2*len(train_set)), AGEMPlugin(patterns_per_experience=11, sample_size=64)]
)

# %%
# TRAINING
results=[]
results = my_utils.cl_simple_train_loop(bm, cl_strategy, model, optimizer, number_of_workers)
# Out:
# Starting experiment with strategy: <avalanche.training.supervised.strategy_wrappers.AGEM object at 0x000001399A9F2A10>
# Start of experience:  0
# Current Classes:  [19, 5]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 2/2 [00:11<00:00,  5.70s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4
# 	StreamForgetting/eval_phase/train_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 1.0000
# Start of experience:  2
# Current Classes:  [0, 3]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 2/2 [01:00<00:00, 30.13s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.4297
# 	Loss_MB/train_phase/train_stream/Task000 = 3.2624
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5482
# 100%|██████████| 2/2 [00:54<00:00, 27.17s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1924
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9219
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5395
# 100%|██████████| 2/2 [00:45<00:00, 22.82s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.2104
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7515
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5395
# 100%|██████████| 2/2 [00:38<00:00, 19.31s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.0756
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9745
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5395
# 100%|██████████| 2/2 [00:38<00:00, 19.36s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9719
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8771
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5395
# 100%|██████████| 2/2 [00:40<00:00, 20.15s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8614
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6899
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6272
# 100%|██████████| 2/2 [00:38<00:00, 19.38s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8057
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6255
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7237
# 100%|██████████| 2/2 [00:38<00:00, 19.44s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7032
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5019
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7456
# 100%|██████████| 2/2 [00:39<00:00, 19.72s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5533
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4664
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7675
# 100%|██████████| 2/2 [00:47<00:00, 23.51s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5486
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4352
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7719
# 100%|██████████| 2/2 [00:45<00:00, 22.61s/it]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5326
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4305
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7719
# 100%|██████████| 2/2 [00:38<00:00, 19.45s/it]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5826
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4615
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7719
# 100%|██████████| 2/2 [00:43<00:00, 21.80s/it]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5451
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2831
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7763
# 100%|██████████| 2/2 [00:46<00:00, 23.40s/it]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5094
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2482
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7763
# 100%|██████████| 2/2 [00:45<00:00, 22.66s/it]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5581
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3742
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7763
# 100%|██████████| 2/2 [00:47<00:00, 23.68s/it]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4081
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2712
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7807
# 100%|██████████| 2/2 [00:46<00:00, 23.41s/it]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4919
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4027
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7763
# 100%|██████████| 2/2 [00:52<00:00, 26.48s/it]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4553
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2749
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7763
# 100%|██████████| 2/2 [00:57<00:00, 28.62s/it]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4769
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4717
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7807
# 100%|██████████| 2/2 [00:56<00:00, 28.32s/it]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4707
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4144
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7807
# -- >> End of training phase << --
# Training completed
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 4/4 [00:08<00:00,  2.14s/it]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 5.2219
# 	Time_Exp/eval_phase/train_stream/Task000/Exp002 = 8.5748
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.5000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 5.2219
# 	StreamForgetting/eval_phase/train_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.5000
# Start of experience:  3
# Current Classes:  [14, 7]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 2/2 [01:02<00:00, 31.38s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.9548
# 	Loss_MB/train_phase/train_stream/Task000 = 3.6520
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4518
# 100%|██████████| 2/2 [01:01<00:00, 30.98s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.4241
# 	Loss_MB/train_phase/train_stream/Task000 = 3.3392
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4912
# 100%|██████████| 2/2 [00:54<00:00, 27.07s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.5189
# 	Loss_MB/train_phase/train_stream/Task000 = 3.2118
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4693
# 100%|██████████| 2/2 [01:10<00:00, 35.36s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.3871
# 	Loss_MB/train_phase/train_stream/Task000 = 3.6340
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4825
# 100%|██████████| 2/2 [00:54<00:00, 27.43s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.2495
# 	Loss_MB/train_phase/train_stream/Task000 = 3.0959
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4649
# 100%|██████████| 2/2 [00:52<00:00, 26.28s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1794
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1634
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4518
# 100%|██████████| 2/2 [00:53<00:00, 26.60s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1198
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8971
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4868
# 100%|██████████| 2/2 [00:55<00:00, 27.67s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.2411
# 	Loss_MB/train_phase/train_stream/Task000 = 3.2150
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4649
# 100%|██████████| 2/2 [00:59<00:00, 29.89s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1942
# 	Loss_MB/train_phase/train_stream/Task000 = 3.1309
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4781
# 100%|██████████| 2/2 [01:00<00:00, 30.05s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.1563
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9471
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6184
# 100%|██████████| 2/2 [00:59<00:00, 29.91s/it]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9767
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6887
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6711
# 100%|██████████| 2/2 [00:58<00:00, 29.14s/it]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9305
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8423
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6798
# 100%|██████████| 2/2 [00:51<00:00, 25.98s/it]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8514
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6765
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7719
# 100%|██████████| 2/2 [00:52<00:00, 26.25s/it]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7480
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6984
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8772
# 100%|██████████| 2/2 [00:55<00:00, 27.64s/it]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.8324
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7748
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8640
# 100%|██████████| 2/2 [01:01<00:00, 30.81s/it]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9458
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9629
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8904
# 100%|██████████| 2/2 [01:03<00:00, 31.58s/it]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6878
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6066
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9561
# 100%|██████████| 2/2 [01:02<00:00, 31.06s/it]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6473
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5320
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9649
# 100%|██████████| 2/2 [00:52<00:00, 26.13s/it]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6020
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4844
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9605
# 100%|██████████| 2/2 [00:51<00:00, 25.95s/it]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6678
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4578
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9693
# -- >> End of training phase << --
# Training completed
# -- >> Start of eval phase << --
# -- Starting eval on experience 3 (Task 0) from train stream --
# 100%|██████████| 4/4 [00:06<00:00,  1.52s/it]
# > Eval on experience 3 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp003 = 3.4718
# 	Time_Exp/eval_phase/train_stream/Task000/Exp003 = 6.0983
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp003 = 1.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 3.4718
# 	StreamForgetting/eval_phase/train_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 1.0000
# Start of experience:  4
# Current Classes:  [20, 15]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 2/2 [00:59<00:00, 29.99s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5311
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3746
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5263
# 100%|██████████| 2/2 [00:58<00:00, 29.08s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2811
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2277
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5307
# 100%|██████████| 2/2 [01:01<00:00, 30.67s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9130
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8148
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6579
# 100%|██████████| 2/2 [00:50<00:00, 25.29s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5826
# 	Loss_MB/train_phase/train_stream/Task000 = 1.4641
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7105
# 100%|██████████| 2/2 [00:59<00:00, 29.94s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3449
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3802
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6974
# 100%|██████████| 2/2 [00:51<00:00, 25.80s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2196
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3008
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6754
# 100%|██████████| 2/2 [00:49<00:00, 24.96s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1540
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1468
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6711
# 100%|██████████| 2/2 [00:49<00:00, 24.83s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1258
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0500
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6535
# 100%|██████████| 2/2 [01:00<00:00, 30.25s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1494
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2961
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6623
# 100%|██████████| 2/2 [00:56<00:00, 28.46s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0952
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2486
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8114
# 100%|██████████| 2/2 [01:00<00:00, 30.02s/it]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1251
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3509
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7807
# 100%|██████████| 2/2 [00:51<00:00, 25.97s/it]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0313
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1188
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8421
# 100%|██████████| 2/2 [00:50<00:00, 25.41s/it]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0494
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2277
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8596
# 100%|██████████| 2/2 [00:49<00:00, 24.84s/it]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0025
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9845
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8596
# 100%|██████████| 2/2 [00:57<00:00, 28.83s/it]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9919
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1273
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8509
# 100%|██████████| 2/2 [01:04<00:00, 32.11s/it]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0333
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2619
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8991
# 100%|██████████| 2/2 [01:00<00:00, 30.20s/it]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9833
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1474
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8991
# 100%|██████████| 2/2 [00:56<00:00, 28.07s/it]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9748
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0519
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8816
# 100%|██████████| 2/2 [01:14<00:00, 37.15s/it]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9595
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0078
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8991
# 100%|██████████| 2/2 [01:08<00:00, 34.49s/it]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9860
# 	Loss_MB/train_phase/train_stream/Task000 = 1.1141
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8860
# -- >> End of training phase << --
# Training completed
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 0) from train stream --
# 100%|██████████| 4/4 [00:08<00:00,  2.21s/it]
# > Eval on experience 4 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp004 = 0.9449
# 	Time_Exp/eval_phase/train_stream/Task000/Exp004 = 8.8581
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp004 = 1.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 0.9449
# 	StreamForgetting/eval_phase/train_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 1.0000
# Start of experience:  5
# Current Classes:  [4, 13]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 2/2 [01:07<00:00, 33.53s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9589
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8066
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5088
# 100%|██████████| 2/2 [00:57<00:00, 28.85s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7002
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5208
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5132
# 100%|██████████| 2/2 [00:55<00:00, 27.60s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3932
# 	Loss_MB/train_phase/train_stream/Task000 = 1.2219
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5789
# 100%|██████████| 2/2 [01:06<00:00, 33.24s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1199
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0933
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6491
# 100%|██████████| 2/2 [00:58<00:00, 29.22s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.0223
# 	Loss_MB/train_phase/train_stream/Task000 = 1.0902
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6404
# 100%|██████████| 2/2 [00:55<00:00, 27.86s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9169
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9548
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6886
# 100%|██████████| 2/2 [00:54<00:00, 27.47s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.8236
# 	Loss_MB/train_phase/train_stream/Task000 = 0.9559
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6930
#  50%|█████     | 1/2 [00:28<00:28, 28.97s/it]

# %%
# SAVE MODEL
my_utils.checkpoint(model, 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_AGEM_CL_1_0.pth')

# %%
# CALCULATE PREDICTIONS
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)

# %%
# PLOT CM
my_utils.plot_confusion_matrix(cm, classes, 'cm_adaptive_AGEM_1_0.png')

# %%
# PLOT F1
my_utils.plot_f1_scores(f1, classes, 'f1_adaptive_AGEM_1_0.png')

# %% [markdown]
# ## AR1 strategy with cross entropy loss and adam

# %%
model = my_architectures.BaselineColorNet_resnet18()
model.to(device)

# %%
# LOSS CRITERION
# AR1 uses SGD, there is no option to change the optimizer
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)

# %%
# AR1 STRATEGY
cl_strategy = AR1(criterion=CrossEntropyLoss(), lr=0.001, inc_lr=0.00005, init_update_rate = 0.01, train_epochs=5,
                  l2 = 0.0005, inc_update_rate = 0.00005, inc_step = 4.1e-05, rm_sz = 2*len(train_set), device=device)

# %%
# TRAINING
results=[]
results = my_utils.cl_simple_train_loop(bm, cl_strategy, model, optimizer, number_of_workers=0)

# %%
# SAVE MODEL
my_utils.checkpoint(model, 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_AR1_CL_1_0.pth')
# Out:
# Saved Pytorch model state to  C:\Users\Brian.Baert\Documents\GitHub\MscThesis\Models\thesis_AR1_CL_1_0.pth

# %%
# CALCULATE PREDICTIONS
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# get_predictions: 82001.85132026672 ms

# %%
# PLOT CM
my_utils.plot_confusion_matrix(cm, classes, 'cm_AR1_1_0.png')

# %%
# PLOT F1
my_utils.plot_f1_scores(f1, classes, 'f1_AR1_1_0.png')
