# %% [markdown]
# <a href="https://colab.research.google.com/github/brianbaert/MscThesis/blob/main/MscThesis_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Packages

# %%
# !python --version
# Out:
# Python 3.10.14

# %%
#!pip install avalanche_lib[all]
#!pip install gwpy
#!pip install nds2
# !pip show avalanche-lib
# !pip show gwpy
# Out:
# Name: avalanche-lib
# Version: 0.5.0
# Summary: Avalanche: a Comprehensive Framework for Continual Learning Research
# Home-page: https://github.com/ContinualAI/avalanche
# Author: ContinualAI
# Author-email: contact@continualai.org
# License:
# Location: c:\programdata\anaconda3\envs\mscthesis\lib\site-packages
# Requires: dill, gdown, gputil, matplotlib, numpy, packaging, psutil, pytorchcv, qpsolvers, scikit-learn, tensorboard, torch, torchmetrics, torchvision, tqdm, typing-extensions, wandb
# Required-by:
# Name: gwpy
# Version: 3.0.8
# Summary: A python package for gravitational-wave astrophysics
# Home-page:
# Author:
# Author-email: Duncan Macleod <duncan.macleod@ligo.org>
# License: GPL-3.0-or-later
# Location: c:\programdata\anaconda3\envs\mscthesis\lib\site-packages
# Requires: astropy, dateparser, dqsegdb2, gwdatafind, gwosc, h5py, ligo-segments, ligotimegps, matplotlib, numpy, python-dateutil, requests, scipy, tqdm
# Required-by:

# %%
 #%cd /content/drive/MyDrive/MscThesis
# %pwd

# %%
import numpy as np
import os
import pandas as pd
import time

from datetime import datetime
from PIL import Image
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.optim import SGD, Adam, AdamW
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import DatasetFolder, ImageFolder
from tqdm import tqdm
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, \
accuracy_score
from avalanche.models import SlimResNet18, MTSlimResNet18, SimpleCNN
from avalanche.models import as_multitask, IncrementalClassifier
from avalanche.models.utils import avalanche_model_adaptation
from avalanche.training import Naive, LwF, GenerativeReplay, ICaRLLossPlugin, ICaRL, EWC, AR1
from avalanche.logging import InteractiveLogger, TextLogger
from avalanche.training.plugins import EvaluationPlugin, ReplayPlugin, LwFPlugin, EarlyStoppingPlugin
from avalanche.training.supervised import VAETraining
from avalanche.benchmarks import nc_benchmark
from avalanche.benchmarks.utils import AvalancheDataset
from avalanche.benchmarks.scenarios.dataset_scenario import benchmark_from_datasets
from avalanche.benchmarks.scenarios.supervised import class_incremental_benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, \
timing_metrics, cpu_usage_metrics, StreamConfusionMatrix,disk_usage_metrics, gpu_usage_metrics, \
confusion_matrix_metrics
import multiprocessing as mp

import my_utils
import my_architectures
import my_dataloaders
import my_gwpy_and_fractals

IMG_SIZE = (224,224)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
number_of_workers = mp.cpu_count()
number_of_workers = int(number_of_workers)
print(number_of_workers)
# Out:
# 8

# %%
#train_dir = '/content/drive/MyDrive/MscThesis/GravitySpy/train/train'
train_dir2 = 'C:\\Users\\Brian.Baert\\TrainingSet'
train_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\train\\train'
#val_dir = '/content/drive/MyDrive/MscThesis/GravitySpy/validation/validation'
val_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\validation\\validation'
#test_dir = '/content/drive/MyDrive/MscThesis/GravitySpy/test/test'
test_dir = 'C:\\Users\\Brian.Baert\\GravitySpy\\test\\test'
#metadata_o3b = '/content/drive/MyDrive/MscThesis/data_o3b_high_confidence.csv'
#metadata_o3a = '/content/drive/MyDrive/MscThesis/data_o3a_high_confidence.csv'
#metadata_o1L1 = '/content/drive/MyDrive/MscThesis/GravitySpy/L1_O1.csv'
#metadata_o2L1 = '/content/drive/MyDrive/MscThesis/GravitySpy/L1_O2.csv'

# %%
meta_train_v1 = pd.read_csv('C:\\Users\\Brian.Baert\\GravitySpy\\trainingset_v1d1_metadata.csv')
print(meta_train_v1[meta_train_v1['sample_type']=='train']['label'].value_counts())
classes = meta_train_v1['label'].unique()
classes
# Out:
# label
# Blip                   1274
# Koi_Fish                498
# Low_Frequency_Burst     437
# Light_Modulation        361
# Extremely_Loud          316
# Low_Frequency_Lines     315
# Power_Line              314
# Scattered_Light         308
# Violin_Mode             284
# Scratchy                237
# 1080Lines               229
# Whistle                 208
# Helix                   195
# Repeating_Blips         185
# No_Glitch               107
# Tomte                    73
# 1400Ripples              59
# None_of_the_Above        57
# Air_Compressor           41
# Chirp                    41
# Wandering_Line           29
# Paired_Doves             19
# Name: count, dtype: int64
# array(['Whistle', '1080Lines', 'Blip', 'Violin_Mode',
#        'Scattered_Light', 'Power_Line', 'Light_Modulation',
#        'Koi_Fish', 'None_of_the_Above', 'Scratchy', 'Tomte',
#        'Chirp', 'Wandering_Line', 'Extremely_Loud',
#        'Repeating_Blips', 'No_Glitch', 'Low_Frequency_Lines',
#        'Paired_Doves', 'Low_Frequency_Burst', 'Helix',
#        'Air_Compressor', '1400Ripples'], dtype=object)

# %%
classes = my_utils.get_classes_from_dir(train_dir2)

# %%
class_to_indx = {c: i for i, c in enumerate(classes)}

# %%
transformGray = transforms.Compose([
     transforms.Resize((140,170)),
     transforms.Grayscale(num_output_channels=1),
     transforms.ToTensor(),
     transforms.Normalize((0.5),(0.5))
    ])

transformRGB = transforms.Compose([
     transforms.Resize((140,170)),
     transforms.Grayscale(num_output_channels=3),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5),(0.5, 0.5, 0.5))
    ])

transformAV = transforms.Compose([
     transforms.Resize((32,32)),
     transforms.ToTensor(),
     transforms.Normalize((0.5),(0.5))
    ])

# Define the bounding box coordinates
top, left, height, width = 60, 100, 480, 580

# Create the custom crop transformation
transformAV2 = transforms.Compose([
    my_utils.CustomCrop(top, left, height, width),
    transforms.Resize((32,32)),
    transforms.ToTensor(),
])

transformAV3 = transforms.Compose([
    my_utils.CustomCrop(top, left, height, width),
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

transformAV_AR1 = transforms.Compose([
     transforms.Resize((224,224)),
     transforms.ToTensor()
     #transforms.Normalize((0.5),(0.5))
    ])

# %% [markdown]
# # DL Baseline

# %%
train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=transformGray)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)
val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=transformGray)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True, num_workers=number_of_workers)
test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=transformGray)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

# %%
train_set = my_dataloaders.GravitySpy_0_5_dataset(root=train_dir, cls=classes, transform=transformGray)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)
val_set = my_dataloaders.GravitySpy_0_5_dataset(root=val_dir, cls=classes, transform=transformGray)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True)
test_set = my_dataloaders.GravitySpy_0_5_dataset(root=test_dir, cls=classes, transform=transformGray)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

# %%
print("The training loader contains {} instances, the val loader contains {} instances and the test loader contains {} instances".format(len(train_loader), len(val_loader), len(test_loader)))

# %%
class_counts = train_set.count_class_instances()
class_weights = []
for class_name, count in class_counts.items():
  print(f"{class_name}: {count} instances")
  class_weights.append(1.0/(count/len(train_set)))

print(class_weights)

# %%
# Create Neural Network architecture for finetuning
myNet = my_architectures.BaselineGrayscaleNet_resnet18()
myNet.to(device)
print(myNet)

# %%
# Pytorch Training loop
epoch_test_loss = 0
epoch_test_acc = 0
epoch_test_correct = 0
epoch_test_total = 0
best_vloss = 1_000_000.
avg_loss = 0
last_loss = 0
timestamp = my_utils.get_timestamp()

# Define the loss function and optimizer
criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)
optimizer = Adam(myNet.parameters(), lr=0.001, weight_decay=1e-3) #LR from the study of Tiago Fernandes

# Number of epochs to train for
num_epochs = 10
epoch_number = 0

start = time.time()
for epoch in range(num_epochs):  # loop over the dataset multiple times
  total_correct = 0
  total_samples = 0
  print('EPOCH {}: '.format(epoch_number + 1))
  train_loss = 0.0
  myNet.train(True)

  ## TRAINING ONE EPOCH
  for i, data in enumerate(train_loader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward + backward + optimize
    outputs = myNet(inputs)
    # compute loss and gradient
    loss = criterion(outputs, labels)
    #add part of regularization
    l2_reg = torch.tensor(0.0)
    for param in myNet.parameters():
      if param.requires_grad: #exclude frozen layers
        l2_reg += torch.norm(param, p=2)
    loss += 1e-5 * l2_reg
    #end part of regularization
    loss.backward()
    # adjust learning weights
    optimizer.step()

    # print statistics
    _, predicted = torch.max(outputs, 1)
    train_loss += loss.item()
    total_correct += (predicted == labels).sum().item()
    total_samples += labels.size(0)

    if i % 16 == 15:
      last_loss = train_loss / 16
      print('  batch {} loss: {}, acc: {}'.format(i+1, last_loss, 100*total_correct/total_samples))
      tb_x = epoch * len(train_loader) + i + 1
      train_loss=0.
    avg_loss = last_loss

  ## VALIDATION
  running_vloss = 0.0
  myNet.eval()

  # disable gradient computation for validation
  with torch.no_grad():
    for i, vdata in enumerate(val_loader):
      vinputs, vlabels = vdata
      vinputs, vlabels = vinputs.to(device), vlabels.to(device)
      voutputs = myNet(vinputs)
      vloss = criterion(voutputs, vlabels)
      running_vloss += vloss
  avg_vloss = running_vloss / (i+1)
  print('LOSS train {:.4f} valid {:.4f} after {} seconds'.format(avg_loss, avg_vloss, time.time()-start))

  if avg_vloss < best_vloss:
    best_vloss = avg_vloss
    model_path = 'model_{}_{}'.format(timestamp, epoch_number)
    torch.save(myNet.state_dict(), model_path)

  #my_utils.checkpoint(myNet, f"epoch-{epoch}.pth")
  epoch_number += 1

end = time.time()
print('Training finished after ', end-start, ' seconds')

# %%
#save model
#torch.save(myNet.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_baseline_finetune_0_5.pth')
torch.save(myNet.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_baseline_finetune_0_5.pth')
print("Saved Pytorch Model state to thesis_baseline.pth")

# %%
#myNet.load_state_dict(torch.load('/content/drive/MyDrive/MscThesis/thesis_baseline_finetune_1_0.pth'))
myNet.load_state_dict(torch.load('C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_baseline_finetune_1_0.pth'))

# %%
my_utils.n_test_predictions(myNet, test_loader, classes, 20)

# %%
y_pred_list, y_true_list = my_utils.get_predictions(myNet, test_loader)

# %%
# Generate confusion matrix
from sklearn.metrics import f1_score
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,7))

# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)

plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('confusion_matrix_baseline_1_0.png')
plt.close()

# %%
print(f"F1 Score for each class: {f1}")
print(f"The average F1 score is: {f1_score(y_true_list, y_pred_list, average='weighted')}")

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_baseline_1_0.png')
plt.close()

# %% [markdown]
# # CL Base model (naive)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = my_architectures.SimpleCNN()

# %%
model.to(device)
interactive_logger = InteractiveLogger()
print(model)

# %%
train_set = my_dataloaders.GravitySpy_dataset(root=train_dir2, cls=classes, transform=transformAV2)
val_set = my_dataloaders.GravitySpy_dataset(root=val_dir, cls=classes, transform=transformAV)
test_set = my_dataloaders.GravitySpy_dataset(root=test_dir, cls=classes, transform=transformAV)

#train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=transformAV2)
#val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=transformAV)
#test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=transformAV)

#train_set = my_dataloaders.GravitySpy_0_5_dataset(root=train_dir, cls=classes, transform=transformAV)
#val_set = my_dataloaders.GravitySpy_0_5_dataset(root=val_dir, cls=classes, transform=transformAV)
#test_set = my_dataloaders.GravitySpy_0_5_dataset(root=test_dir, cls=classes, transform=transformAV)

#train_set = my_dataloaders.GravitySpy_1_0_dataset(root=train_dir, cls=classes, transform=transformAV_AR1)
#val_set = my_dataloaders.GravitySpy_1_0_dataset(root=val_dir, cls=classes, transform=transformAV_AR1)
#test_set = my_dataloaders.GravitySpy_1_0_dataset(root=test_dir, cls=classes, transform=transformAV_AR1)

train_set_av = AvalancheDataset(train_set)
train_loader_av = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=number_of_workers)

val_set_av = AvalancheDataset(val_set)
val_loader_av = torch.utils.data.DataLoader(val_set, batch_size=16, shuffle=True, num_workers=number_of_workers)

test_set_av = AvalancheDataset(test_set)
test_loader_av = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)

train_set_av.targets = train_set.labels
test_set_av.targets = test_set.labels
val_set_av.targets = val_set.labels

train_set_av.uniques = list(set(train_set.labels))
test_set_av.uniques = list(set(test_set.labels))
val_set_av.uniques = list(set(val_set.labels))

# %%
for batch in train_loader_av:
    images, labels = batch
    grid = torchvision.utils.make_grid(images, nrow=4, padding=2, normalize=True)
    grid_np = grid.numpy().transpose((1,2,0))
    plt.imshow(grid_np)
    plt.axis('off')
    plt.show()
    break

# %%
bm = nc_benchmark(
    train_dataset=train_set_av,
    test_dataset=val_set_av,
    n_experiences=11,
    shuffle=False,
    seed=123,
    task_labels=False,
    class_ids_from_zero_in_each_exp=False,
)

# %%
# DEFINE THE EVALUATION PLUGIN, OPTIMIZER AND STRATEGY
# The evaluation plugin manages the metrics computation.
# It takes as argument a list of metrics, collectes their results and returns
# them to the strategy it is attached to.

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(experience=True),
    forgetting_metrics(experience=True, stream=True),
    confusion_matrix_metrics(num_classes=bm.n_classes, save_image=True, stream=True),
    loggers=[InteractiveLogger()],
    strict_checks=False,
)

optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-3)
#criterion = CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32), label_smoothing=0.2)
criterion = CrossEntropyLoss(label_smoothing=0.2)

cl_strategy = Naive(
    model=model, optimizer=optimizer, criterion=criterion, train_mb_size=32, train_epochs=1, eval_mb_size=16, device=device, evaluator=eval_plugin, plugins=[ReplayPlugin(mem_size=2000), EarlyStoppingPlugin(patience=2, val_stream_name='valid')]
)

# %%
#do not execute together with the next cell --> causes unwanted classifier adjustments
for experience in bm.train_stream:
    print(experience.classes_in_this_experience)
    model.adaptation(experience)

# %%
print('Starting experiment...')
results = []
for experience in bm.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    print(len(experience.classes_in_this_experience))
    cl_strategy.train(experience, num_workers=4)
    print('Training completed')
    if model.classifier.out_features != 22:
        model.adaptation(experience)
    print(model.classifier)
# Out:
# Starting experiment...
# Start of experience:  0
# Current Classes:  [0, 1]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:27<00:00,  2.11s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6957
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6931
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4900
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  4
# Linear(in_features=64, out_features=4, bias=True)
# Start of experience:  1
# Current Classes:  [2, 3]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:31<00:00,  2.40s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3880
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3893
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2412
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  6
# Linear(in_features=64, out_features=6, bias=True)
# Start of experience:  2
# Current Classes:  [4, 5]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:32<00:00,  2.52s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7838
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7961
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2365
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  8
# Linear(in_features=64, out_features=8, bias=True)
# Start of experience:  3
# Current Classes:  [6, 7]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:33<00:00,  2.59s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0246
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0935
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1397
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  10
# Linear(in_features=64, out_features=10, bias=True)
# Start of experience:  4
# Current Classes:  [8, 9]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:33<00:00,  2.60s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2991
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2807
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1287
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  12
# Linear(in_features=64, out_features=12, bias=True)
# Start of experience:  5
# Current Classes:  [10, 11]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:33<00:00,  2.60s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4756
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4782
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0490
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  14
# Linear(in_features=64, out_features=14, bias=True)
# Start of experience:  6
# Current Classes:  [12, 13]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:34<00:00,  2.66s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5975
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5816
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0711
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  16
# Linear(in_features=64, out_features=16, bias=True)
# Start of experience:  7
# Current Classes:  [14, 15]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:33<00:00,  2.55s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6627
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7028
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1826
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  18
# Linear(in_features=64, out_features=18, bias=True)
# Start of experience:  8
# Current Classes:  [16, 17]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:32<00:00,  2.53s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7972
# 	Loss_MB/train_phase/train_stream/Task000 = 2.7085
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0833
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  20
# Linear(in_features=64, out_features=20, bias=True)
# Start of experience:  9
# Current Classes:  [18, 19]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:33<00:00,  2.59s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9287
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9011
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0907
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  22
# Linear(in_features=64, out_features=22, bias=True)
# Start of experience:  10
# Current Classes:  [20, 21]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:33<00:00,  2.59s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.9451
# 	Loss_MB/train_phase/train_stream/Task000 = 2.9788
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1115
# -- >> End of training phase << --
# Training completed
# Linear(in_features=64, out_features=22, bias=True)

# %%
#save model
torch.save(model.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_Naive_CL_1_0.pth')
#torch.save(model.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_generative_CL_1_0.pth')
print("Saved Pytorch Model state to thesis_Naive_CL_1_0.pth")
# Out:
# Saved Pytorch Model state to thesis_Naive_CL_1_0.pth

# %%
model = SimpleCNN(num_classes=22)
#model.load_state_dict(torch.load('C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_Naive_CL_1_0.pth'))
model.load_state_dict(torch.load('C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_Naive_CL_1_0.pth'))
#model.load_state_dict(torch.load('/content/drive/MyDrive/MscThesis/thesis_generative_CL_1_0.pth'))
model.eval()
# Out:
# SimpleCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.25, inplace=False)
#     (12): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): AdaptiveMaxPool2d(output_size=1)
#     (15): Dropout(p=0.25, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=64, out_features=22, bias=True)
#   )
# )

# %%
my_utils.n_test_predictions(model, test_loader_av, classes, 20)
# Out:
# Predicted: "Blip", Actual: "Low_Frequency_Lines"
# Predicted: "Blip", Actual: "Helix"
# Predicted: "Blip", Actual: "Low_Frequency_Burst"
# Predicted: "Blip", Actual: "Violin_Mode"
# Predicted: "Violin_Mode", Actual: "Koi_Fish"
# Predicted: "Blip", Actual: "1080Lines"
# Predicted: "Blip", Actual: "Scattered_Light"
# Predicted: "Blip", Actual: "Power_Line"
# Predicted: "Blip", Actual: "Blip"
# Predicted: "Blip", Actual: "Whistle"
# Predicted: "Blip", Actual: "Scattered_Light"
# Predicted: "Blip", Actual: "Scattered_Light"
# Predicted: "Blip", Actual: "Blip"
# Predicted: "Extremely_Loud", Actual: "Light_Modulation"
# Predicted: "Blip", Actual: "Power_Line"
# Predicted: "Blip", Actual: "Helix"
# Predicted: "Blip", Actual: "Violin_Mode"
# Predicted: "Blip", Actual: "Scattered_Light"
# Predicted: "Blip", Actual: "Low_Frequency_Burst"
# Predicted: "Blip", Actual: "1080Lines"
# n_test_predictions: 499.6647834777832 ms

# %%
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# get_predictions: 104184.28707122803 ms

# %%
# Generate confusion matrix
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
plt.figure(figsize=(10,7))

# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)

plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
#figTemp.savefig('f1_scores_Naive_1_0.png')
plt.close()

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
#figTemp.savefig('f1_scores_Naive_1_0.png')
plt.close()

# %% [markdown]
# ## LwF strategy

# %%
model = my_architectures.SimpleCNN()
model.to(device)
interactive_logger = InteractiveLogger()
print(model)
# Out:
# SimpleCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.25, inplace=False)
#     (12): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): AdaptiveMaxPool2d(output_size=1)
#     (15): Dropout(p=0.25, inplace=False)
#   )
#   (classifier): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
cl_strategy = LwF(
    model=model, optimizer=optimizer, criterion=criterion, alpha=0.25, temperature=2.0, train_mb_size=32, train_epochs=10, eval_mb_size=32, device=device, evaluator=eval_plugin, plugins=[ReplayPlugin(mem_size=4400), EarlyStoppingPlugin(patience=2, val_stream_name='valid')]
)

#alpha and temperature are taken from the paper by Oren & Wolf - "In defense of the Learning Without Forgetting for Task Incremental Learning"

# %%
print('Starting experiment with LwF...')
results = []
for experience in bm.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)
    print(len(experience.classes_in_this_experience))
    cl_strategy.train(experience, num_workers=number_of_workers)
    print('Training completed')
    if model.classifier.out_features != 22:
        model.adaptation(experience)
    print(model.classifier)
    results.append(cl_strategy.evaluator.all_metric_results)
# Out:
# Starting experiment with LwF...
# Start of experience:  0
# Current Classes:  [0, 1]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:43<00:00,  3.37s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6945
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6943
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4475
# 100%|██████████| 13/13 [00:41<00:00,  3.22s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6934
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6935
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4875
# 100%|██████████| 13/13 [00:43<00:00,  3.32s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6937
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6954
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5150
# 100%|██████████| 13/13 [00:43<00:00,  3.32s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6933
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6966
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5300
# 100%|██████████| 13/13 [00:42<00:00,  3.27s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6947
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6844
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4525
# 100%|██████████| 13/13 [00:43<00:00,  3.31s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6936
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6948
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4775
# 100%|██████████| 13/13 [00:43<00:00,  3.31s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6937
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6854
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5025
# 100%|██████████| 13/13 [00:42<00:00,  3.30s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6927
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6911
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5325
# 100%|██████████| 13/13 [00:41<00:00,  3.22s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6928
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6977
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4975
# 100%|██████████| 13/13 [00:42<00:00,  3.26s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.6935
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6873
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4850
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  4
# Linear(in_features=64, out_features=4, bias=True)
# Start of experience:  1
# Current Classes:  [2, 3]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:44<00:00,  3.44s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3886
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3866
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2487
# 100%|██████████| 13/13 [00:44<00:00,  3.46s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3862
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3875
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2500
# 100%|██████████| 13/13 [00:44<00:00,  3.44s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3872
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3848
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2325
# 100%|██████████| 13/13 [00:46<00:00,  3.56s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3864
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3909
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2475
# 100%|██████████| 13/13 [00:45<00:00,  3.51s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3861
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3835
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2637
# 100%|██████████| 13/13 [00:46<00:00,  3.61s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3868
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3900
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2437
# 100%|██████████| 13/13 [00:45<00:00,  3.51s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3865
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3907
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2387
# 100%|██████████| 13/13 [00:45<00:00,  3.48s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3868
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3884
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2500
# 100%|██████████| 13/13 [00:45<00:00,  3.46s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3862
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3886
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2437
# 100%|██████████| 13/13 [00:45<00:00,  3.52s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3860
# 	Loss_MB/train_phase/train_stream/Task000 = 1.3835
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2338
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  6
# Linear(in_features=64, out_features=6, bias=True)
# Start of experience:  2
# Current Classes:  [4, 5]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:45<00:00,  3.46s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7871
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8012
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2451
# 100%|██████████| 13/13 [00:46<00:00,  3.60s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7686
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7868
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2316
# 100%|██████████| 13/13 [00:44<00:00,  3.42s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7052
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7384
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2451
# 100%|██████████| 13/13 [00:45<00:00,  3.46s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6040
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6787
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2451
# 100%|██████████| 13/13 [00:45<00:00,  3.46s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5826
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6532
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3076
# 100%|██████████| 13/13 [00:46<00:00,  3.57s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5510
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6483
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4498
# 100%|██████████| 13/13 [00:45<00:00,  3.47s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5190
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6299
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4534
# 100%|██████████| 13/13 [00:45<00:00,  3.52s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5102
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5962
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4485
# 100%|██████████| 13/13 [00:44<00:00,  3.46s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5015
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5912
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4461
# 100%|██████████| 13/13 [00:44<00:00,  3.41s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4790
# 	Loss_MB/train_phase/train_stream/Task000 = 1.5410
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4632
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  8
# Linear(in_features=64, out_features=8, bias=True)
# Start of experience:  3
# Current Classes:  [6, 7]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:45<00:00,  3.49s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9517
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9926
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2292
# 100%|██████████| 13/13 [00:48<00:00,  3.72s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8469
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8917
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3027
# 100%|██████████| 13/13 [00:49<00:00,  3.78s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8255
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8782
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3027
# 100%|██████████| 13/13 [00:45<00:00,  3.53s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8076
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9736
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3480
# 100%|██████████| 13/13 [00:45<00:00,  3.49s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7743
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8447
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3897
# 100%|██████████| 13/13 [00:45<00:00,  3.47s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7619
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7909
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4044
# 100%|██████████| 13/13 [00:45<00:00,  3.53s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7340
# 	Loss_MB/train_phase/train_stream/Task000 = 1.6936
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4400
# 100%|██████████| 13/13 [00:47<00:00,  3.67s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7427
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7845
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4118
# 100%|██████████| 13/13 [00:53<00:00,  4.12s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7180
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7767
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4252
# 100%|██████████| 13/13 [00:50<00:00,  3.90s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7161
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7590
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4314
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  10
# Linear(in_features=64, out_features=10, bias=True)
# Start of experience:  4
# Current Classes:  [8, 9]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:53<00:00,  4.11s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0416
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1468
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3076
# 100%|██████████| 13/13 [00:45<00:00,  3.50s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9176
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1171
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4154
# 100%|██████████| 13/13 [00:47<00:00,  3.65s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8813
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9923
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4375
# 100%|██████████| 13/13 [00:45<00:00,  3.51s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8439
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9150
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4694
# 100%|██████████| 13/13 [00:45<00:00,  3.52s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8098
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9765
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4792
# 100%|██████████| 13/13 [00:47<00:00,  3.62s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7431
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9396
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5294
# 100%|██████████| 13/13 [00:45<00:00,  3.51s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7109
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8789
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5270
# 100%|██████████| 13/13 [00:45<00:00,  3.52s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6883
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8489
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5515
# 100%|██████████| 13/13 [00:46<00:00,  3.58s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6438
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7223
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5858
# 100%|██████████| 13/13 [00:45<00:00,  3.49s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6414
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7015
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5944
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  12
# Linear(in_features=64, out_features=12, bias=True)
# Start of experience:  5
# Current Classes:  [10, 11]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:47<00:00,  3.67s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0229
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1383
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4056
# 100%|██████████| 13/13 [00:46<00:00,  3.60s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9254
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1342
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5466
# 100%|██████████| 13/13 [00:44<00:00,  3.44s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8253
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0145
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5699
# 100%|██████████| 13/13 [00:45<00:00,  3.47s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7746
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0034
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5821
# 100%|██████████| 13/13 [00:45<00:00,  3.46s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7654
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8943
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6201
# 100%|██████████| 13/13 [00:47<00:00,  3.62s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7431
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9231
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6091
# 100%|██████████| 13/13 [00:53<00:00,  4.10s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.7026
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8811
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6238
# 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6704
# 	Loss_MB/train_phase/train_stream/Task000 = 1.7674
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6373
# 100%|██████████| 13/13 [01:14<00:00,  5.73s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6630
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8195
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6409
# 100%|██████████| 13/13 [00:58<00:00,  4.52s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.6600
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8053
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6471
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  14
# Linear(in_features=64, out_features=14, bias=True)
# Start of experience:  6
# Current Classes:  [12, 13]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:52<00:00,  4.03s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2765
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2207
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2819
# 100%|██████████| 13/13 [00:56<00:00,  4.34s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0974
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2044
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4032
# 100%|██████████| 13/13 [01:04<00:00,  4.98s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9746
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1092
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5282
# 100%|██████████| 13/13 [00:53<00:00,  4.08s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9309
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9283
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5429
# 100%|██████████| 13/13 [00:52<00:00,  4.04s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8864
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9757
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5882
# 100%|██████████| 13/13 [00:45<00:00,  3.52s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8615
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9902
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5809
# 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8376
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9008
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6029
# 100%|██████████| 13/13 [00:58<00:00,  4.50s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8877
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0089
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5613
# 100%|██████████| 13/13 [00:55<00:00,  4.27s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8503
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0254
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5882
# 100%|██████████| 13/13 [00:54<00:00,  4.17s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.8286
# 	Loss_MB/train_phase/train_stream/Task000 = 1.8797
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5882
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  16
# Linear(in_features=64, out_features=16, bias=True)
# Start of experience:  7
# Current Classes:  [14, 15]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:53<00:00,  4.14s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4431
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2943
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2684
# 100%|██████████| 13/13 [00:55<00:00,  4.25s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1113
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2260
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4767
# 100%|██████████| 13/13 [00:51<00:00,  3.96s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0804
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1783
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4902
# 100%|██████████| 13/13 [00:47<00:00,  3.65s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0481
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1001
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5159
# 100%|██████████| 13/13 [00:53<00:00,  4.12s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9951
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1073
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5417
# 100%|██████████| 13/13 [01:09<00:00,  5.34s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9565
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0617
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5650
# 100%|██████████| 13/13 [01:09<00:00,  5.33s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9494
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0069
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5576
# 100%|██████████| 13/13 [00:57<00:00,  4.39s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9551
# 	Loss_MB/train_phase/train_stream/Task000 = 1.9588
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5699
# 100%|██████████| 13/13 [00:53<00:00,  4.13s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9352
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1223
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5784
# 100%|██████████| 13/13 [00:54<00:00,  4.19s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9380
# 	Loss_MB/train_phase/train_stream/Task000 = 2.0677
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5882
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  18
# Linear(in_features=64, out_features=18, bias=True)
# Start of experience:  8
# Current Classes:  [16, 17]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:46<00:00,  3.59s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3772
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2322
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3260
# 100%|██████████| 13/13 [00:45<00:00,  3.54s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2030
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1504
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4547
# 100%|██████████| 13/13 [00:55<00:00,  4.25s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1209
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3236
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5172
# 100%|██████████| 13/13 [00:53<00:00,  4.15s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0488
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1071
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5576
# 100%|██████████| 13/13 [00:58<00:00,  4.47s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0275
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1627
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5748
# 100%|██████████| 13/13 [00:55<00:00,  4.28s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0131
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2576
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5637
# 100%|██████████| 13/13 [00:58<00:00,  4.47s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9800
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1970
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5895
# 100%|██████████| 13/13 [00:54<00:00,  4.20s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9583
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1592
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5993
# 100%|██████████| 13/13 [00:54<00:00,  4.16s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9851
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1671
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5931
# 100%|██████████| 13/13 [00:54<00:00,  4.20s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.9611
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2927
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6042
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  20
# Linear(in_features=64, out_features=20, bias=True)
# Start of experience:  9
# Current Classes:  [18, 19]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:54<00:00,  4.17s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3820
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4850
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3223
# 100%|██████████| 13/13 [00:56<00:00,  4.35s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2729
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4161
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4265
# 100%|██████████| 13/13 [00:55<00:00,  4.29s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2000
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2345
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4473
# 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2145
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2741
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4620
# 100%|██████████| 13/13 [00:48<00:00,  3.72s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1575
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2276
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4804
# 100%|██████████| 13/13 [00:48<00:00,  3.76s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1416
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1679
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4890
# 100%|██████████| 13/13 [00:46<00:00,  3.58s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0966
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2268
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5306
# 100%|██████████| 13/13 [00:48<00:00,  3.73s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1459
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3677
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5025
# 100%|██████████| 13/13 [00:48<00:00,  3.71s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1283
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2574
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5037
# 100%|██████████| 13/13 [00:51<00:00,  3.95s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1098
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2349
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5061
# -- >> End of training phase << --
# Training completed
# Current classes:  2
# New classes:  22
# Linear(in_features=64, out_features=22, bias=True)
# Start of experience:  10
# Current Classes:  [20, 21]
# 2
# -- >> Start of training phase << --
# 100%|██████████| 13/13 [00:48<00:00,  3.72s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6106
# 	Loss_MB/train_phase/train_stream/Task000 = 2.6246
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.2953
# 100%|██████████| 13/13 [00:49<00:00,  3.78s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.4205
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5539
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3787
# 100%|██████████| 13/13 [00:46<00:00,  3.58s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3595
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4693
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4228
# 100%|██████████| 13/13 [00:47<00:00,  3.65s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.3148
# 	Loss_MB/train_phase/train_stream/Task000 = 2.5834
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4314
# 100%|██████████| 13/13 [00:46<00:00,  3.59s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2716
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4494
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4718
# 100%|██████████| 13/13 [00:54<00:00,  4.16s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2413
# 	Loss_MB/train_phase/train_stream/Task000 = 2.3519
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4804
# 100%|██████████| 13/13 [00:57<00:00,  4.39s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.2183
# 	Loss_MB/train_phase/train_stream/Task000 = 2.4313
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4902
# 100%|██████████| 13/13 [00:54<00:00,  4.16s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1969
# 	Loss_MB/train_phase/train_stream/Task000 = 2.1518
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5025
# 100%|██████████| 13/13 [00:56<00:00,  4.38s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1656
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2251
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5123
# 100%|██████████| 13/13 [00:57<00:00,  4.39s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.1414
# 	Loss_MB/train_phase/train_stream/Task000 = 2.2329
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5172
# -- >> End of training phase << --
# Training completed
# Linear(in_features=64, out_features=22, bias=True)

# %%
#save model
torch.save(model.state_dict(), 'C:\\Users\\Brian.Baert\\Documents\\GitHub\\MscThesis\\Models\\thesis_LwF_CL_1_0.pth')
#torch.save(model.state_dict(), '/content/drive/MyDrive/MscThesis/thesis_generative_CL_1_0.pth')
print("Saved Pytorch Model state to thesis_LwF_CL_1_0.pth")

#calculate predictions
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
# Out:
# Saved Pytorch Model state to thesis_LwF_CL_1_0.pth
# get_predictions: 99030.62844276428 ms

# %%
# Generate confusion matrix
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)

# %%
plt.figure(figsize=(10,7))
# Use seaborn heatmap for visualization
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_LwF_1_0.png')
plt.close()

# %%
# Create a horizontal bar plot for F1 scores with different colors
plt.figure(figsize=(10,7))
colors = plt.cm.viridis(np.linspace(0, 1, len(classes)))
plt.barh(np.arange(len(classes)), f1, color=colors, align='center', alpha=0.5)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel('F1 Score')
plt.title('F1 Score for Each Class')
figTemp = plt.gcf()
plt.show()
plt.draw()
figTemp.savefig('f1_scores_LwF_1_0.png')
plt.close()

# %%
from avalanche.benchmarks import SplitMNIST
from avalanche.models import IncrementalClassifier

benchmark = SplitMNIST(11, shuffle=False, class_ids_from_zero_in_each_exp=False)
model = IncrementalClassifier(in_features=784)

print(model)
for exp in benchmark.train_stream:
    model.adaptation(exp)
    print(model)
