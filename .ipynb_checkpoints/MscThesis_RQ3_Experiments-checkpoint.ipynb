# %%
import numpy as np
import os
import pandas as pd
import time
import umap
import numba
from pathlib import Path
from datetime import datetime
from PIL import Image
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.image as mpImage
import seaborn as sns
import torch
import torch.optim as optim
import torchvision
import torchvision.models
import torchvision.transforms as transforms
from torch.optim import SGD, Adam, AdamW
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import DatasetFolder, ImageFolder
from tqdm import tqdm
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, \
accuracy_score, precision_score
from avalanche.models import SlimResNet18, MTSlimResNet18, SimpleCNN
from avalanche.models import as_multitask, IncrementalClassifier
from avalanche.models.utils import avalanche_model_adaptation
from avalanche.training import Naive, LwF, GenerativeReplay, ICaRLLossPlugin, ICaRL, EWC, AR1, LFL, AGEM, DER
from avalanche.logging import (
    InteractiveLogger,
    TextLogger,
    CSVLogger,
)
from avalanche.training.plugins import EvaluationPlugin, ReplayPlugin, LwFPlugin, EarlyStoppingPlugin, AGEMPlugin
from avalanche.training.plugins.lr_scheduling import LRSchedulerPlugin
from avalanche.benchmarks import nc_benchmark, ni_benchmark
from avalanche.benchmarks.utils import AvalancheDataset
from avalanche.benchmarks.scenarios.dataset_scenario import benchmark_from_datasets
from avalanche.benchmarks.scenarios.supervised import class_incremental_benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, \
timing_metrics, cpu_usage_metrics, StreamConfusionMatrix, disk_usage_metrics, gpu_usage_metrics, \
confusion_matrix_metrics, bwt_metrics, forward_transfer_metrics, ram_usage_metrics, images_samples_metrics, \
class_accuracy_metrics, mean_scores_metrics
from avalanche.evaluation.metrics import Accuracy, BWT, Forgetting, ForwardTransfer
#import multiprocessing as mp
import my_utils
import my_architectures
import my_dataloaders
# import my_gwpy_and_fractals
import my_transformations
IMG_SIZE = (224,224)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# calculating the amount of workers usable
number_of_workers = 4

label_mapping = {0: 'No_Glitch', 1: 'Whistle', 2: 'Tomte', 3: 'Scattered_Light'}
# Replace values using the dictionary
#classes = ['No_Glitch', 'Whistle', 'Tomte', 'Scattered_Light']
classes = ['Whistle', 'Tomte', 'Scattered_Light']
print(classes)
# Out:
# ['Whistle', 'Tomte', 'Scattered_Light']

# %%
# Setting the correct directories
#train_dir = 'D:\\Users\\Brian\\TrainingSet_CL_1\\TrainingSet_CL_1'
#image_dir = 'C:\\Users\\Brian.Baert\\FD_CL\\images\\images'
train_dir = 'D:\\Users\\Brian\\FD_CL\\images\\images'
#test_dir = 'C:\\Users\Brian.Baert\\FD_CL\\images\\test'
test_dir = 'D:\\Users\Brian\\FD_CL\\images\\test'
#FD_location = 'C:\\Users\Brian.Baert\\FD_CL\\reduced_ids_50.npy'
FD_location = 'D:\\Users\Brian\\FD_CL\\reduced_ids_50.npy'

#Load in fratal data
fractal_matrices = np.load(FD_location)
fractal_matrices.shape

#Three classes
classes = ['Whistle', 'Tomte', 'Scattered_Light']

#First image ID = 896

#Label the instances
train_labels = []
train_labels.extend(['Whistle'] * 876)
train_labels.extend(['Tomte'] * 876)
train_labels.extend(['Scattered_Light'] * 876)
test_labels = []
test_labels.extend(['Whistle'] * 20)
test_labels.extend(['Tomte'] * 20)
test_labels.extend(['Scattered_Light'] * 20)
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
fractal_matrices.shape
# Out:
# (2688, 50, 56)

# %%
fractal_matrices[0]
# Out:
# array([[0.57451844, 0.574585  , 0.61747295, ..., 0.8614793 , 0.8710429 ,
#         0.86270547],
#        [0.82187957, 0.8134645 , 0.8314725 , ..., 0.87468857, 0.8983555 ,
#         0.89641106],
#        [0.48615664, 0.5589393 , 0.5859381 , ..., 0.81507933, 0.76803046,
#         0.7939468 ],
#        ...,
#        [0.58207494, 0.478571  , 0.5393343 , ..., 0.7123621 , 0.6273871 ,
#         0.64899284],
#        [0.45105952, 0.30550978, 0.43062353, ..., 0.39758435, 0.5520664 ,
#         0.39632282],
#        [0.40403458, 0.32956344, 0.49127063, ..., 0.8159749 , 0.73265237,
#         0.83331215]], dtype=float32)

# %%
import re
def find_index(filename):
    match = re.search(r'\d+', filename)
    if match:
        n_index = match.group(0)
        return(int(n_index)-896)

# %%
test = 'img_896.png'
print(find_index(test))
# Out:
# 0

# %%
test_indices = []
for class_name in classes:
    classpath = os.path.join(test_dir, class_name)
    for file in os.listdir(classpath):
        test_indices.append(find_index(file))

# %%
len(test_indices)
# Out:
# 60

# %%
test_fractal_matrices = np.zeros((60,50,56))
j = 0
for i in test_indices:
    test_fractal_matrices[j] = fractal_matrices[i]
    j = j + 1

# %%
test_fractal_matrices.shape
# Out:
# (60, 50, 56)

# %%
temp = np.delete(fractal_matrices, test_indices, axis=0)
train_fractal_matrices = temp

# %%
train_fractal_matrices.shape
# Out:
# (2628, 50, 56)

# %%
import torch
from sklearn.preprocessing import LabelEncoder
train_fractal_matrices = torch.from_numpy(train_fractal_matrices).float()  
test_fractal_matrices = torch.from_numpy(test_fractal_matrices).float()
# Create a label encoder
le = LabelEncoder()
# Fit the encoder on the training labels
le.fit(train_labels)
le.fit(test_labels)
# Convert string labels to numerical labels
Y_train_encoded = le.transform(train_labels)
Y_test_encoded = le.transform(test_labels)
# Convert the encoded labels to a long tensor
train_labels = torch.from_numpy(Y_train_encoded).long()
test_labels = torch.from_numpy(Y_test_encoded).long()

# %%
train_labels
# Out:
# tensor([2, 2, 2,  ..., 0, 0, 0])

# %%
for class_name in classes:
    classpath = os.path.join(train_dir, class_name)
    print(classpath)
    for file in os.listdir(classpath):
        print(f"{file}")
        indx = find_index(file)
        print(train_labels[indx])
        plt.imshow(fractal_matrices[indx])
        plt.show()
        print(type(file))
        plt.imshow(mpImage.imread(os.path.join(classpath,file)))
        plt.show()
        break
    break
# Out:
# D:\Users\Brian\FD_CL\images\images\Whistle
# img_1000.png
# tensor(2)
# <class 'str'>

# %%
train_dataset = my_dataloaders.FractalImages(root=train_dir, cls=classes, transform=my_transformations.transformFD_Image)
test_dataset = my_dataloaders.FractalImages(root=test_dir, cls=classes, transform=my_transformations.transformFD_Image)

# %%
(train_fractal_matrices).shape
# Out:
# torch.Size([2628, 50, 56])

# %%
train_labels.shape
# Out:
# torch.Size([2628])

# %%
torch.as_tensor(train_labels)
# Out:
# tensor([2, 2, 2,  ..., 0, 0, 0])

# %%
train_fd_dataset = my_dataloaders.FractalDataset(train_fractal_matrices , train_labels)
test_fd_dataset = my_dataloaders.FractalDataset(test_fractal_matrices , test_labels)
train_fd_dataset_av = AvalancheDataset(train_fd_dataset)
test_fd_dataset_av = AvalancheDataset(test_fd_dataset)

# %%
train_fd_dataset_av.targets = [label.tolist() for i, label in enumerate(train_fd_dataset.labels)]
test_fd_dataset_av.targets = [label.tolist() for i, label in enumerate(test_fd_dataset.labels)]
train_fd_dataset_av.uniques = list(set(train_fd_dataset.labels))
test_fd_dataset_av.uniques = list(set(test_fd_dataset.labels))

# %%
train_fd_loader_av = torch.utils.data.DataLoader(train_fd_dataset, batch_size=16, shuffle=True, num_workers=number_of_workers)
test_fd_loader_av = torch.utils.data.DataLoader(test_fd_dataset, batch_size=1, shuffle=False)

# %%
batch = next(iter(train_fd_dataset))
matrix, label = batch
print(matrix.shape)
print(label)
# Out:
# torch.Size([50, 56])
# tensor(2)

# %%
train_set_av = AvalancheDataset(train_dataset)
train_loader_av = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=number_of_workers)
train_set_av.targets = [label for i, label in enumerate(train_dataset.labels)]
train_set_av.uniques = list(set(train_dataset.labels))
test_set_av = AvalancheDataset(test_dataset)
test_loader_av = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)
test_set_av.targets = [label for i, label in enumerate(test_dataset.labels)]
test_set_av.uniques = list(set(test_dataset.labels))

# %%
model = my_architectures.MultiViewColorNet_resnet18(num_classes=3)
model.to(device)

# log to text file
text_logger = TextLogger(open("multiview_fusion_naive_log_100epochs.txt", "a"))
# print to stdout
interactive_logger = InteractiveLogger()
csv_logger = CSVLogger()

bm = nc_benchmark(
    train_dataset=train_set_av,
    test_dataset=test_set_av,
    n_experiences=3,
    shuffle=True,
    seed=1234,
    task_labels=False,
    class_ids_from_zero_in_each_exp=False,
)

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    forgetting_metrics(experience=False, stream=True),
    ram_usage_metrics(experience=True, stream=True, epoch=False),
    bwt_metrics(experience=True, stream=True),
    loggers=[interactive_logger, text_logger, csv_logger],
    strict_checks=False,
)

# log to text file
text_logger = TextLogger(open("Logs/RQ3_log.txt", "a"))
# print to stdout
interactive_logger = InteractiveLogger()
csv_logger = CSVLogger()
class_to_indx = my_utils.classes_to_indices(classes)

# OPTIMIZER and CRITERION
optimizer = AdamW(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = CrossEntropyLoss()

# %%
# STRATEGY
cl_strategy = DER(
    model=model, optimizer=optimizer, criterion=criterion, alpha=1.0, beta=0, mem_size=500,
    train_mb_size=64, train_epochs=10, eval_mb_size=16, device=device, evaluator=eval_plugin,
)

# %%
# TRAINING
results=[]
results = my_utils.cl_simple_train_loop(bm, cl_strategy, model, optimizer, number_of_workers, classes, 'RQ3_DER', scr=False)
# Out:
# Starting experiment with strategy: <avalanche.training.supervised.der.DER object at 0x0000025D72676770>
# Start of experience:  0
# Current Classes:  [0]
# -- >> Start of training phase << --
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:29<00:00,  2.12s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.2772
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9645
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.96s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0120
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.95s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0030
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.97s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0015
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.93s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0011
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.98s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0011
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.94s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0009
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.99s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0011
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.98s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0149
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:27<00:00,  1.95s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0078
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Start of experience:  1
# Current Classes:  [2]
# -- >> Start of training phase << --
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:32<00:00,  6.61s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.2596
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7482
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:32<00:00,  6.61s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.4896
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9406
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.57s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.2609
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9553
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.54s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1034
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9621
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.54s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.9676
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9683
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.51s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.8918
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9706
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.51s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.8143
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9791
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.55s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.7262
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9791
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.53s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.7247
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9836
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:32<00:00,  6.60s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.7895
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9683
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.58it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 1.7041
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.37it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp001 = 4030.2500
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 1.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.62it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 15.0771
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp002 = 4043.8203
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 5.5937
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task000 = 4043.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.6333
# Start of experience:  2
# Current Classes:  [1]
# -- >> Start of training phase << --
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:30<00:00,  6.43s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 17.6379
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4856
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:30<00:00,  6.46s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 8.6948
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7852
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:29<00:00,  6.42s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 6.3527
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9327
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:30<00:00,  6.47s/it]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 6.4463
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9520
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:30<00:00,  6.50s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.5445
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9661
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:29<00:00,  6.39s/it]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.5751
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9774
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:31<00:00,  6.53s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.9813
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9819
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:29<00:00,  6.42s/it]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.0854
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9802
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:32<00:00,  6.59s/it]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 5.3544
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9813
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [01:29<00:00,  6.40s/it]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.6776
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9819
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.97it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 2.6943
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4500
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.50it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp001 = -0.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0002
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp001 = 4045.0977
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 1.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.58it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp002 = 4058.6172
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 1.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.8981
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task000 = 4058.6172
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8167
# Stored metrics: ['Top1_Acc_Epoch/train_phase/train_stream/Task000', 'Loss_Epoch/train_phase/train_stream/Task000', 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000', 'Loss_Exp/eval_phase/test_stream/Task000/Exp000', 'MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000', 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001', 'Loss_Exp/eval_phase/test_stream/Task000/Exp001', 'MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp001', 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002', 'Loss_Exp/eval_phase/test_stream/Task000/Exp002', 'MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp002', 'Top1_Acc_Stream/eval_phase/test_stream/Task000', 'Loss_Stream/eval_phase/test_stream/Task000', 'StreamForgetting/eval_phase/test_stream', 'MaxRAMUsage_Stream/eval_phase/test_stream/Task000', 'StreamBWT/eval_phase/test_stream', 'ExperienceBWT/eval_phase/test_stream/Task000/Exp001']
# cl_simple_train_loop: 2184640.594959259 ms

# %%
# SAVE MODEL
my_utils.checkpoint(model, 'Models/thesis_RQ3_ImageModel.pth')
# Out:
# Saved Pytorch model state to  Models/thesis_RQ3_ImageModel.pth

# %%
# LOAD MODEL
temp = torch.load('Models/thesis_RQ3_ImageModel.pth', map_location=torch.device(device))
model.load_state_dict(temp)
# Out:
# <All keys matched successfully>

# %%
# CALCULATE ALL PREDICTIONS
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model, test_loader_av)
print(classification_report(y_true_list, y_pred_list, target_names=classes))
# Out:
# get_predictions: 1862.6034259796143 ms
#                  precision    recall  f1-score   support
#
#         Whistle       1.00      0.45      0.62        20
#           Tomte       0.67      1.00      0.80        20
# Scattered_Light       0.95      1.00      0.98        20
#
#        accuracy                           0.82        60
#       macro avg       0.87      0.82      0.80        60
#    weighted avg       0.87      0.82      0.80        60

# %%
my_utils.plot_tSNE_data_embedding(model, test_loader, classes, "Results/tSNE_RQ3_ImageModel_test.png")
# Out:
# D:\Users\Brian\MscThesis_env\lib\site-packages\threadpoolctl.py:1223: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# plot_tSNE_data_embedding: 4345.290184020996 ms

# %%
reducer = umap.UMAP(n_neighbors=15, metric='euclidean', n_components=2, spread=0.5, min_dist=0.2, densmap=True)
my_utils.plot_umap_data_embedding(model, test_loader, classes, reducer, "Results/umap_RQ3_ImageModel_test.png")
# Out:
# plot_umap_data_embedding: 23576.696157455444 ms

# %%
# GENERATE CONFUSION MATRIX AND F1
cm = confusion_matrix(y_true_list, y_pred_list)
f1 = f1_score(y_true_list, y_pred_list, average=None)
my_utils.plot_confusion_matrix(cm, classes, 'Results/cm_RQ3_ImageModel.png')
my_utils.plot_f1_scores(f1, classes, 'Results/f1_RQ3_ImageModel.png')

# %% [markdown]
# ## FD model

# %%
# Create an instance of the CNN architecture
model2 = my_architectures.FractalDimensionConvNet()
model2.apply(my_utils.weights_init)

bm = nc_benchmark(
    train_dataset=train_fd_dataset_av,
    test_dataset=test_fd_dataset_av,
    n_experiences=3,
    shuffle=True,
    seed=1234,
    task_labels=False
)

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    class_accuracy_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=False, epoch=True, experience=True, stream=True),
    forgetting_metrics(experience=True, stream=True),
    bwt_metrics(experience=True, stream=True),
    mean_scores_metrics(on_train=True, on_eval=True),
    loggers=[interactive_logger, text_logger, csv_logger],
    strict_checks=False,
)

# OPTIMIZER and CRITERION
optimizer = AdamW(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = CrossEntropyLoss()

# NAIVE STRATEGY
cl_strategy = Naive(
    model=model, optimizer=optimizer, criterion=criterion, train_mb_size=16, train_epochs=15, 
    eval_mb_size=1, device=device, evaluator=eval_plugin, 
    plugins=[ReplayPlugin(mem_size=2*len(train_fd_dataset)), EarlyStoppingPlugin(patience=2, val_stream_name='Loss_Epoch')]
)

# %%
# TRAINING
results2=[]
results2 = my_utils.cl_simple_train_loop(bm, cl_strategy, model2, optimizer, number_of_workers, classes, 'naive_fd')
# Out:
# Starting experiment with strategy: <avalanche.training.supervised.strategy_wrappers.Naive object at 0x0000025D75998220>
# Start of experience:  0
# Current Classes:  [0]
# -- >> Start of training phase << --
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[58], line 3
#       1 # TRAINING
#       2 results2=[]
# ----> 3 results2 = my_utils.cl_simple_train_loop(bm, cl_strategy, model2, optimizer, number_of_workers, classes, 'naive_fd')
#
# File D:\Users\Brian\MscThesis\my_utils.py:49, in timeit.<locals>.timed(*args, **kw)
#      47 def timed(*args, **kw):
#      48     ts = time.time()
# ---> 49     result = method(*args, **kw)
#      50     te = time.time()
#      51     print(f'{method.__name__}: {(te - ts) * 1000} ms')
#
# File D:\Users\Brian\MscThesis\my_utils.py:244, in cl_simple_train_loop(bm, cl_strategy, model, optimizer, number_of_workers, classes, name, scr)
#     241 print("Current Classes: ", experience.classes_in_this_experience)
#     243 # train one experience
# --> 244 res = cl_strategy.train(experience)
#     245 print("Training completed")
#     247 if torch.cuda.is_available():
#     248     # Get initial classification layer weights after training
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\avalanche\training\templates\base_sgd.py:211, in BaseSGDTemplate.train(self, experiences, eval_streams, **kwargs)
#     203 def train(
#     204     self,
#     205     experiences: Union[TDatasetExperience, Iterable[TDatasetExperience]],
#    (...)
#     209     **kwargs
#     210 ):
# --> 211     super().train(experiences, eval_streams, **kwargs)
#     212     return self.evaluator.get_last_metrics()
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\avalanche\training\templates\base.py:163, in BaseTemplate.train(self, experiences, eval_streams, **kwargs)
#     161 for self.experience in experiences_list:
#     162     self._before_training_exp(**kwargs)
# --> 163     self._train_exp(self.experience, eval_streams, **kwargs)
#     164     self._after_training_exp(**kwargs)
#     165 self._after_training(**kwargs)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\avalanche\training\templates\base_sgd.py:337, in BaseSGDTemplate._train_exp(self, experience, eval_streams, **kwargs)
#     334     self._stop_training = False
#     335     break
# --> 337 self.training_epoch(**kwargs)
#     338 self._after_training_epoch(**kwargs)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\avalanche\training\templates\update_type\sgd_update.py:31, in SGDUpdate.training_epoch(self, **kwargs)
#      29 # Forward
#      30 self._before_forward(**kwargs)
# ---> 31 self.mb_output = self.forward()
#      32 self._after_forward(**kwargs)
#      34 # Loss & Backward
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\avalanche\training\templates\problem_type\supervised_problem.py:47, in SupervisedProblem.forward(self)
#      45 def forward(self):
#      46     """Compute the model's output given the current mini-batch."""
# ---> 47     return avalanche_forward(self.model, self.mb_x, self.mb_task_id)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\avalanche\models\utils.py:22, in avalanche_forward(model, x, task_labels)
#      20     return model(x, task_labels)
#      21 else:  # no task labels
# ---> 22     return model(x)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File D:\Users\Brian\MscThesis\my_architectures.py:108, in MultiViewColorNet_resnet18.forward(self, x)
#     106 def forward(self, x):
#     107   # Forward pass: compute the output of the model by passing the input through the model
# --> 108   x = self.resnet(x)
#     109   # Apply batch normalization
#     110   x = self.bn(x)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torchvision\models\resnet.py:268, in ResNet._forward_impl(self, x)
#     266 def _forward_impl(self, x: Tensor) -> Tensor:
#     267     # See note [TorchScript super()]
# --> 268     x = self.conv1(x)
#     269     x = self.bn1(x)
#     270     x = self.relu(x)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File D:\Users\Brian\MscThesis_env\lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [64, 3, 7, 7], expected input[1, 16, 50, 56] to have 3 channels, but got 16 channels instead

# %%
# SAVE MODEL
my_utils.checkpoint(model2, 'Models/thesis_RQ3_FDModel.pth')

# %%
# LOAD MODEL
temp = torch.load('Models/thesis_RQ2_FDModel_DER.pth', map_location=torch.device(device))
model2.load_state_dict(temp)
# Out:
# <All keys matched successfully>

# %%
# CALCULATE ALL PREDICTIONS
test_loader = torch.utils.data.DataLoader(test_fd_dataset, batch_size=1, shuffle=True)
y_pred_list, y_true_list = my_utils.get_predictions(model2, test_loader)
print(classification_report(y_true_list, y_pred_list, target_names=classes))
# Out:
# get_predictions: 346.41242027282715 ms
#                  precision    recall  f1-score   support
#
#         Whistle       0.87      1.00      0.93        20
#           Tomte       1.00      0.95      0.97        20
# Scattered_Light       1.00      0.90      0.95        20
#
#        accuracy                           0.95        60
#       macro avg       0.96      0.95      0.95        60
#    weighted avg       0.96      0.95      0.95        60

# %%
matrix, label = next(iter(test_loader))
print(matrix)
print(label)
# Out:
# tensor([[[0.5389, 0.5477, 0.5708,  ..., 0.8464, 0.8475, 0.8293],
#          [0.8336, 0.8315, 0.8372,  ..., 0.8948, 0.8916, 0.9050],
#          [0.4760, 0.4988, 0.4938,  ..., 0.7579, 0.7580, 0.7708],
#          ...,
#          [0.4322, 0.6683, 0.4046,  ..., 0.7088, 0.5852, 0.6090],
#          [0.5804, 0.5961, 0.5294,  ..., 0.6881, 0.5573, 0.6063],
#          [0.1630, 0.1954, 0.1660,  ..., 0.7315, 0.9550, 0.8789]]])
# tensor([2])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
model.eval()
with torch.no_grad():
        for inputs, labels in test_loader_av:
            inputs, labels = inputs.to(device), labels.to(device)
            # Forward pass: compute predicted outputs by passing inputs to the model
            outputs = model(inputs)
            print(outputs)
            # Get the index of the maximum value
            _, preds = torch.max(outputs, 1)
            print(preds)
# Out:
# tensor([[ 5.0073, -4.5740, -4.0189]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[-0.4679,  0.9874, -2.1869]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-0.6697,  1.2182, -2.2826]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.3489,  1.9560, -2.5766]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 0.4387,  0.0400, -2.0488]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 3.1324, -2.0966, -4.3948]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 4.0766, -3.5640, -3.3403]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 2.7320, -2.4030, -2.2506]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[-1.0679,  1.5921, -2.2673]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.3210,  1.9046, -2.4787]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 2.1876, -1.8747, -1.8399]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[-2.5741,  3.2459, -3.3794]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-0.8198,  1.4055, -2.4349]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-2.6942,  3.4123, -3.5538]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.4242,  2.0201, -2.5748]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 4.5218, -3.7270, -3.8539]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[-8.2897, -8.5436, 13.1718]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[ 4.2689, -3.7248, -3.4737]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 0.0958,  0.4258, -2.1781]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 4.0102, -3.5587, -3.2989]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[-6.4195,  7.9578, -8.2465]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.2848,  6.6348, -6.8408]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.7826,  7.2066, -7.4464]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-4.9882,  6.2258, -6.4290]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.7735,  7.2364, -7.4566]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-4.9005,  6.0297, -6.2741]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.3491,  6.6377, -6.8749]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.7364,  7.1646, -7.3953]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.0977,  6.3724, -6.5739]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-4.8431,  6.0618, -6.2478]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.7235,  7.1465, -7.3759]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-6.1270,  7.5850, -7.8660]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.4691,  6.7992, -7.0324]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.9844,  7.4093, -7.6867]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.4031,  6.7393, -6.9621]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.3493,  6.6723, -6.8928]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.6773,  7.0195, -7.2874]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-4.4453,  5.5382, -5.7254]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-5.9438,  7.3666, -7.6340]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-6.4641,  8.0211, -8.3092]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-13.1397, -12.9912,  21.1468]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-13.9392, -13.9743,  22.6842]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-15.0441, -15.0620,  24.4950]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-13.0902, -13.1769,  21.3334]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-11.3725, -12.7271,  19.3225]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-8.3438, -9.5349, 14.3672]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-11.1653, -11.9916,  18.1865]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-11.5273, -11.4037,  18.5689]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-12.2441, -12.1997,  19.7609]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-11.2100, -11.7989,  18.5997]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-12.9911, -12.9882,  21.0679]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-13.2510, -13.1663,  21.4697]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-9.3465, -9.4840, 14.9482]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-14.5757, -14.6787,  23.7833]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-11.9585, -12.6560,  19.9276]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-11.3203, -11.1943,  18.1401]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[ -9.6508, -10.7672,  16.4731]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-3.9572, -2.2512,  3.5652]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-14.8734, -14.8669,  24.1900]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[-12.1541, -12.0713,  19.5684]], device='cuda:0')
# tensor([2], device='cuda:0')

# %%
model2 = model2.to(device)
model2.eval()
with torch.no_grad():
        for inputs, labels in test_fd_loader_av:
            inputs, labels = inputs.to(device), labels.to(device)
            # Forward pass: compute predicted outputs by passing inputs to the model
            outputs = model2(inputs)
            print(outputs)
            # Get the index of the maximum value
            _, preds = torch.max(outputs, 1)
            print(preds)
# Out:
# tensor([[  5.0371, -12.5270,   9.8168]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[ 8.1496, -6.9093,  2.3897]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[  5.1627, -10.8562,   7.3339]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.4913, -13.0594,   9.2094]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.7279, -13.9474,  10.1837]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  5.0132, -13.6995,   9.3712]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[ 23.1359,  -8.9671, -11.0398]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 3.8237, -9.5151,  7.3063]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.5167, -12.9961,   8.4502]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.4834, -13.6364,   8.6227]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  3.3696, -21.7060,  12.1547]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.8325, -23.4190,  15.0033]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.5739, -23.8692,  14.4016]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  5.2356, -19.4915,  12.5853]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  5.5753, -16.8699,  11.7755]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  3.4245, -25.7500,  15.2170]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  4.9332, -20.3203,  12.1718]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  5.4739, -18.3768,  12.0883]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  5.3957, -21.6272,  14.0894]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[  5.5466, -19.6496,  13.5704]], device='cuda:0')
# tensor([2], device='cuda:0')
# tensor([[ -1.9062,  13.7457, -11.2930]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 1.0445,  1.2378, -0.5331]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.1653,  8.2652, -7.5357]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.0930,  4.1213, -5.3980]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.7022, 10.9979, -8.8656]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 0.1199,  9.2351, -8.9282]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ -2.0820,  23.2658, -19.2270]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ -0.4936,  21.6360, -24.9807]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-0.5402,  4.5919, -3.8032]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[  0.1679,  17.0029, -25.7093]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ -2.2759,  17.7827, -23.6490]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[  0.7744,  18.0827, -17.7684]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ -2.2814,  15.0356, -13.3392]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-0.2844,  4.8621, -4.6575]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.3554, 10.2899, -9.4198]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.5327,  8.1087, -5.9059]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 2.1379,  0.1594, -1.3605]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ -1.6249,  14.8059, -13.2985]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[-1.0818,  9.9421, -8.5146]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ -1.5479,  12.3433, -10.5995]], device='cuda:0')
# tensor([1], device='cuda:0')
# tensor([[ 36.4781, -21.8294, -18.4357]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 29.9903, -16.3569, -14.5508]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 31.0594, -19.4912, -14.0329]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 31.4380, -16.0934, -16.2169]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 31.1563, -17.6799, -13.8941]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 38.2310, -22.9028, -17.8812]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 33.9946, -17.6133, -17.2783]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 34.6807, -19.2028, -16.0063]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 33.9422, -19.5532, -14.9017]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 40.8911, -24.0721, -19.9930]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 37.4156, -21.0272, -17.8354]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 29.5939, -15.8343, -14.1633]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 34.8371, -20.1140, -16.1999]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 32.0229, -18.1707, -14.3441]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 30.3507, -17.7166, -13.0054]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 34.1666, -17.8455, -16.3457]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 32.6994, -18.0237, -14.5563]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 33.2930, -16.8837, -15.5675]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 37.4948, -22.2268, -17.2744]], device='cuda:0')
# tensor([0], device='cuda:0')
# tensor([[ 29.2055, -16.4466, -14.4586]], device='cuda:0')
# tensor([0], device='cuda:0')
